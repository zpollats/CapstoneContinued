# %% [markdown]
# # Long Term Stock Performance Prediction

# %% [markdown]
# ## Business Understanding and Overview

# %% [markdown]
# For decades, many humans have attempted to predict the stock market. These attempts have varied in nature from predicting individual stock prices to predicting the direction of the overall market. While most argue that it's impossible to beat the market as an individual investor, I believe that with the right tools and technology, individuals can indeed outperform the market. While I believe this idea is possible, the data shows that individual investors' performances are dreadful on average when compared to the broader market. The bar chart below shows that the average investor had annual returns of 1.9% from 1999-2018 while the S&P500 returned 5.6%.

# %% [markdown]
#  ![](images/IndInvInfographic.jpeg)

# %% [markdown]
# Currently, to be a well-versed individual investor requires significant time researching companies, listening to earnings calls, and having an understanding of macro-economic trends. Most people do not have the time to become knowledgable on multiple companies that are publicly traded, so it's easier and safer to invest in index funds that track the overall market. But what if there was a tool that could quickly let individual investors know which companies can beat the market over an extended period of time?

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# I have sourced all the required data myself using the SEC's API. I used this API to pull the annual reports (10-K) for public companies from 2009-2012. I could not get any useful data from before 2009 because the SEC didn't require companies to file in XBRL format until then. In the future, I plan to use other methods to acquire and clean data prior to 2009. I stopped collecting data past 2012 because I need a 10 year window to determine if a stock outperformed the market over 10 years based on their financials.
#
# In terms of metrics that I will use to score the performance of my model, recall will be the most important metric followed by precision. Recall will score how my model does at identifying stocks that do outperform the market. Investors will care more about finding the stocks that can outperform the market rather than correctly identifying those that underperform. Precision will also be a key metric because this gives a score for how accurate our model performs when predicting that a stock does outperform the market. To simplify the metrics I use, I can also use the f1 score as this is the harmonic mean of precision and recall.

# %%
# import all relevant libraries
from IPython.display import Image

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 

import pickle
import time
import requests
import json
from sec_api import QueryApi

import yfinance as yf
from sec_cik_mapper import StockMapper

import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# I am using base code from https://gist.github.com/janlukasschroeder/3da274150fd00c1c1776c7e541a9b61b to get me started in scraping financial statements from the SEC. I will be using 10-K forms (annual SEC filing) rather than all quarterly filings (10-Q) to reduce the size of data.
#
# This Github user's project gave me base code for functions that convert xbrl data to json format, pull relevant financial documents (balance sheet, income statement, etc.), and run queries through the SEC API.

# %%
# XBRL-to-JSON converter API endpoint
xbrl_converter_api_endpoint = "https://api.sec-api.io/xbrl-to-json"

# %%
# convert XBRL-JSON of balance sheet to pandas dataframe
def get_balance_sheet(xbrl_json):
    
    """
    This function takes in the json data for a given SEC filing and returns a pandas dataframe of \
    the financial information relevant to the balance sheet.
    """
    
    # create an empty dictionary to begin storing financial info
    balance_sheet_store = {}

    # loop through each financial item in the BalanceSheets portion of the json data
    for usGaapItem in xbrl_json['BalanceSheets']:
        values = []
        indicies = []

        for fact in xbrl_json['BalanceSheets'][usGaapItem]:
            # only consider items without segment.
            if 'segment' not in fact:
                index = fact['period']['instant']

                # avoid duplicate indicies with same values
                if index in indicies:
                    continue
                    
                # add 0 if value is nil
                if "value" not in fact:
                    values.append(0)
                else:
                    values.append(fact['value'])

                indicies.append(index)                    
            
            # create a pandas series for each financial item
            balance_sheet_store[usGaapItem] = pd.Series(values, index=indicies) 

    # combine all pandas series into a dataframe        
    balance_sheet = pd.DataFrame(balance_sheet_store).reset_index()
    # create a column that is the year for the period the financials are reported for
    balance_sheet['index'] = balance_sheet['index'].str.slice(-10, -6)
    balance_sheet = balance_sheet.rename(columns={'index': 'year'})
    balance_sheet = balance_sheet.sort_values(by='year')
    # create a column for the central index key, as we will use this to get the stock ticker symbol later
    balance_sheet['CIK'] = xbrl_json['CoverPage']['EntityCentralIndexKey']
    balance_sheet = pd.DataFrame(balance_sheet.iloc[-1, :]).T

    return balance_sheet

# %%
#### convert XBRL-JSON of income statement to pandas dataframe
def get_income_statement(xbrl_json):
    
    """
    This function takes in the json data for a given SEC filing and returns a pandas dataframe of \
    the financial information relevant to the income statement.
    """
    
    # create an empty dictionary to begin storing financial info
    income_statement_store = {}

    # iterate over each US GAAP item in the income statement
    for usGaapItem in xbrl_json['StatementsOfIncome']:
        values = []
        indicies = []

        for fact in xbrl_json['StatementsOfIncome'][usGaapItem]:
            # only consider items without segment. not required for our analysis.
            if 'segment' not in fact:
                index = fact['period']['startDate'] + '-' + fact['period']['endDate']
                # ensure no index duplicates are created
                if index not in indicies:
                    values.append(fact['value'])
                    indicies.append(index)                    
        
        # save the items for each financial data piece into a pandas series
        income_statement_store[usGaapItem] = pd.Series(values, index=indicies) 

    # combine all pandas series into a dataframe
    income_statement = pd.DataFrame(income_statement_store).reset_index()
    # pull out the year from the date range and create a new column for the year
    income_statement['index'] = income_statement['index'].str.slice(-10, -6)
    income_statement = income_statement.rename(columns={'index': 'year'})
    income_statement = income_statement.sort_values(by='year')
    # create a column for the Central Index Key as this will be used to get stock ticker symbols later on 
    income_statement['CIK'] = xbrl_json['CoverPage']['EntityCentralIndexKey']
    income_statement = pd.DataFrame(income_statement.iloc[-1, :]).T
    
    return income_statement

# %%
def get_cash_flow_statement(xbrl_json):
    
    """
    This function takes in the json data for a given SEC filing and returns a pandas dataframe of \
    the financial information relevant to the cash flow statement.
    """
    
    # create empty dictionary to begin storing relevant financial info
    cash_flows_store = {}

    # iterate through each financial item in the cash flow statement
    for usGaapItem in xbrl_json['StatementsOfCashFlows']:
        values = []
        indicies = []

        for fact in xbrl_json['StatementsOfCashFlows'][usGaapItem]:        
            # only consider items without segment.
            if 'segment' not in fact:
                # check if date instant or date range is present
                if "instant" in fact['period']:
                    index = fact['period']['instant']
                else:
                    index = fact['period']['startDate'] + '-' + fact['period']['endDate']

                # avoid duplicate indicies with same values
                if index in indicies:
                    continue

                if "value" not in fact:
                    values.append(0)
                else:
                    values.append(fact['value'])

                indicies.append(index)                    
        
        # create a pandas series for each financial item
        cash_flows_store[usGaapItem] = pd.Series(values, index=indicies) 

    # combine all pandas series into one dataframe
    cash_flows = pd.DataFrame(cash_flows_store).reset_index()
    # create a column for the year from which the financial data was reported
    cash_flows['index'] = cash_flows['index'].str.slice(-10, -6)
    cash_flows = cash_flows.rename(columns={'index': 'year'})
    cash_flows = cash_flows.sort_values(by='year')
    # create a column for the Central Index Key as this will be used to get stock ticker symbols later on
    cash_flows['CIK'] = xbrl_json['CoverPage']['EntityCentralIndexKey']
    cash_flows = pd.DataFrame(cash_flows.iloc[-2, :]).T
    
    return cash_flows

# %%
import datetime

# create a start and end date to collect financial documents
start = datetime.datetime.strptime("2021-01-01", "%Y-%m-%d")
end = datetime.datetime.strptime("2021-12-31", "%Y-%m-%d")
date_generated = [start + datetime.timedelta(days=x) for x in range(0, (end-start).days)]
    
# only take every 7 days (weekly intervals)
cleaned_dates = []
for date in date_generated[::7]:
    cleaned_dates.append(date.strftime("%Y-%m-%d"))
    
cleaned_dates[:5]
# Out:
# ['2021-01-01', '2021-01-08', '2021-01-15', '2021-01-22', '2021-01-29']

# %%
# create a list of date ranges that we can run our query on 
cleaned_date_range = [f"{cleaned_dates[i]} TO {cleaned_dates[i+1]}" for i in range(len(cleaned_dates) - 1)]
cleaned_date_range[:5]
# Out:
# ['2021-01-01 TO 2021-01-08',
#  '2021-01-08 TO 2021-01-15',
#  '2021-01-15 TO 2021-01-22',
#  '2021-01-22 TO 2021-01-29',
#  '2021-01-29 TO 2021-02-05']

# %%
my_tickers = pd.read_excel('BUDGET.xlsx', sheet_name='Stock Allocation')

# %%
ticker_list = list(my_tickers['Ticker'].dropna())
ticker_list
# Out:
# ['MELI',
#  'AMZN',
#  'CRWD',
#  'NVDA',
#  'SHOP',
#  'LULU',
#  'ROKU',
#  'SWAV',
#  'SQ',
#  'TWLO',
#  'PYPL',
#  'LMND',
#  'MDB',
#  'ACN',
#  'TEAM',
#  'ASML',
#  'KNSL',
#  'PUBM',
#  'U',
#  'DIS',
#  'MGNI',
#  'PINS',
#  'MA',
#  'TDOC',
#  'AMD',
#  'FLGT',
#  'AMT',
#  'LTCH',
#  'ESTC',
#  'V',
#  'DAVA',
#  'ILMN',
#  'FVRR',
#  'PI',
#  'TWST',
#  'COIN',
#  'MASI',
#  'MMM',
#  'DOCU',
#  'AYX',
#  'CFLT',
#  'FSLY',
#  'TER',
#  'OPAD',
#  'WIX',
#  'STNE',
#  'STOR',
#  'CHWY',
#  'ARBK',
#  'SEMR',
#  'JMIA',
#  'SKLZ',
#  'UBX']

# %%
full_query = []
query_api = QueryApi(api_key='88140c3a554da7220ba7453a5e1ea2221c5f1e0e42c3293bbe75857245774e2e')

# loop through the date range created and pull all 10-K forms that were reported within the date range
for ticker in ticker_list:
    query = {
        "query": {
            "query_string": {
                "query": f"(formType:\"10-K\") AND (ticker:{ticker})"
                             }
                },
        "size": "200",
        "sort": [{ "filedAt": { "order": "desc" } }]
        }

    full_query.append(query_api.get_filings(query)['filings'])

# %%
#create an empty list to fill with accession numbers
accession_numbers = []

# extract accession numbers of each filing
for filing in full_query:
    for item in filing:
        accession_numbers.append(item['accessionNo']);

# %%
full_query
# Out:
# [[{'id': '436b5ee548ca16a833420bd59ff84299',
#    'accessionNo': '0001562762-22-000049',
#    'cik': '1099590',
#    'ticker': 'MELI',
#    'companyName': 'MERCADOLIBRE INC',
#    'companyNameLong': 'MERCADOLIBRE INC (Filer)',
#    'formType': '10-K',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'filedAt': '2022-02-23T16:02:19-05:00',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/0001562762-22-000049.txt',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/0001562762-22-000049-index.htm',
#    'linkToXbrl': '',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/meli-20211231x10k.htm',
#    'entities': [{'companyName': 'MERCADOLIBRE INC (Filer)',
#      'cik': '1099590',
#      'irsNo': '980212790',
#      'fiscalYearEnd': '1231',
#      'type': '10-K',
#      'act': '34',
#      'fileNo': '001-33647',
#      'filmNo': '22663383',
#      'sic': '7389 Services-Business Services, NEC'}],
#    'documentFormatFiles': [{'sequence': '1',
#      'description': '10-K',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/1099590/000156276222000049/meli-20211231x10k.htm',
#      'type': '10-K',
#      'size': '12339052'},
#     {'sequence': '2',
#      'description': 'EX-4.08',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/meli-20211231xex4_08.htm',
#      'type': 'EX-4.08',
#      'size': '57896'},
#     {'sequence': '3',
#      'description': 'EX-4.07',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/meli-20211231xex4_7.htm',
#      'type': 'EX-4.7',
#      'size': '249012'},
#     {'sequence': '4',
#      'description': 'EX-21.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/meli-20211231xex21_1.htm',
#      'type': 'EX-21.1',
#      'size': '58149'},
#     {'sequence': '5',
#      'description': 'EX-22.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/meli-20211231xex22_01.htm',
#      'type': 'EX-22.01',
#      'size': '11598'},
#     {'sequence': '6',
#      'description': 'EX-23.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/meli-20211231xex23_1.htm',
#      'type': 'EX-23.1',
#      'size': '8295'},
#     {'sequence': '7',
#      'description': 'EX-31.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/meli-20211231xex31_1.htm',
#      'type': 'EX-31.1',
#      'size': '35649'},
#     {'sequence': '8',
#      'description': 'EX-31.02',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/meli-20211231xex31_2.htm',
#      'type': 'EX-31.2',
#      'size': '30893'},
#     {'sequence': '9',
#      'description': 'EX-32.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/meli-20211231xex32_1.htm',
#      'type': 'EX-32.1',
#      'size': '11288'},
#     {'sequence': '10',
#      'description': 'EX-32.02',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/meli-20211231xex32_2.htm',
#      'type': 'EX-32.2',
#      'size': '11765'},
#     {'sequence': '11',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/meli-20211231x10kg001.jpg',
#      'type': 'GRAPHIC',
#      'size': '36405'},
#     {'sequence': '12',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/meli-20211231xex23_1g001.jpg',
#      'type': 'GRAPHIC',
#      'size': '23772'},
#     {'sequence': '\xa0',
#      'description': 'Complete submission text file',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/0001562762-22-000049.txt',
#      'type': '\xa0',
#      'size': '23656550'}],
#    'dataFiles': [{'sequence': '13',
#      'description': 'EX-101.SCH',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/meli-20211231.xsd',
#      'type': 'EX-101.SCH',
#      'size': '144035'},
#     {'sequence': '14',
#      'description': 'EX-101.CAL',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/meli-20211231_cal.xml',
#      'type': 'EX-101.CAL',
#      'size': '180630'},
#     {'sequence': '15',
#      'description': 'EX-101.DEF',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/meli-20211231_def.xml',
#      'type': 'EX-101.DEF',
#      'size': '571799'},
#     {'sequence': '16',
#      'description': 'EX-101.LAB',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/meli-20211231_lab.xml',
#      'type': 'EX-101.LAB',
#      'size': '1020665'},
#     {'sequence': '17',
#      'description': 'EX-101.PRE',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/meli-20211231_pre.xml',
#      'type': 'EX-101.PRE',
#      'size': '922923'},
#     {'sequence': '138',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276222000049/meli-20211231x10k_htm.xml',
#      'type': 'XML',
#      'size': '1472181'}],
#    'seriesAndClassesContractsInformation': [],
#    'periodOfReport': '2021-12-31'},
#   {'ticker': 'MELI',
#    'formType': '10-K',
#    'accessionNo': '0001562762-21-000079',
#    'cik': '1099590',
#    'companyNameLong': 'MERCADOLIBRE INC (Filer)',
#    'effectivenessDate': '2020-12-31',
#    'companyName': 'MERCADOLIBRE INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/meli-20201231x10k.htm',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/0001562762-21-000079.txt',
#    'filedAt': '2021-03-01T16:26:47-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '11857920',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/1099590/000156276221000079/meli-20201231x10k.htm',
#      'description': '10-K',
#      'type': '10-K'},
#     {'sequence': '2',
#      'size': '248274',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/meli-20201231xex4_07.htm',
#      'description': 'EX-4.07',
#      'type': 'EX-4.07'},
#     {'sequence': '3',
#      'size': '49314',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/meli-20201231xex21_01.htm',
#      'description': 'EX-21.01',
#      'type': 'EX-21.01'},
#     {'sequence': '4',
#      'size': '7648',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/meli-20201231xex23_01.htm',
#      'description': 'EX-23.01',
#      'type': 'EX-23.01'},
#     {'sequence': '5',
#      'size': '35457',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/meli-20201231xex31_01.htm',
#      'description': 'EX-31.01',
#      'type': 'EX-31.01'},
#     {'sequence': '6',
#      'size': '33542',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/meli-20201231xex31_02.htm',
#      'description': 'EX-31.02',
#      'type': 'EX-31.02'},
#     {'sequence': '7',
#      'size': '11085',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/meli-20201231xex32_01.htm',
#      'description': 'EX-32.01',
#      'type': 'EX-32.01'},
#     {'sequence': '8',
#      'size': '11480',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/meli-20201231xex32_02.htm',
#      'description': 'EX-32.02',
#      'type': 'EX-32.02'},
#     {'sequence': '9',
#      'size': '39780',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/meli-20201231x10kg001.jpg',
#      'description': 'GRAPHIC',
#      'type': 'GRAPHIC'},
#     {'sequence': '10',
#      'size': '23772',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/meli-20201231xex23_01g001.jpg',
#      'description': 'GRAPHIC',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '39571965',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/0001562762-21-000079.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2020-12-31',
#    'entities': [{'fiscalYearEnd': '1231',
#      'act': '34',
#      'cik': '1099590',
#      'fileNo': '001-33647',
#      'irsNo': '980212790',
#      'companyName': 'MERCADOLIBRE INC (Filer)',
#      'type': '10-K',
#      'sic': '7389 Services-Business Services, NEC',
#      'filmNo': '21698203'}],
#    'id': '8f73f90904932dfb6ecfe314f3e76719',
#    'seriesAndClassesContractsInformation': [],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/0001562762-21-000079-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '11',
#      'size': '131426',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/meli-20201231.xsd',
#      'description': 'EX-101.SCH',
#      'type': 'EX-101.SCH'},
#     {'sequence': '12',
#      'size': '171486',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/meli-20201231_cal.xml',
#      'description': 'EX-101.CAL',
#      'type': 'EX-101.CAL'},
#     {'sequence': '13',
#      'size': '532541',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/meli-20201231_def.xml',
#      'description': 'EX-101.DEF',
#      'type': 'EX-101.DEF'},
#     {'sequence': '14',
#      'size': '961986',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/meli-20201231_lab.xml',
#      'description': 'EX-101.LAB',
#      'type': 'EX-101.LAB'},
#     {'sequence': '15',
#      'size': '887907',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/meli-20201231_pre.xml',
#      'description': 'EX-101.PRE',
#      'type': 'EX-101.PRE'},
#     {'sequence': '16',
#      'size': '10222069',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276221000079/meli-20201231x10k_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]},
#   {'ticker': 'MELI',
#    'formType': '10-K/A',
#    'accessionNo': '0001562762-20-000435',
#    'cik': '1099590',
#    'companyNameLong': 'MERCADOLIBRE INC (Filer)',
#    'effectivenessDate': '2019-12-31',
#    'companyName': 'MERCADOLIBRE INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000435/meli-20191231x10ka.htm',
#    'description': 'Form 10-K/A - Annual report [Section 13 and 15(d), not S-K Item 405]: [Amend]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000435/0001562762-20-000435.txt',
#    'filedAt': '2020-12-23T16:34:50-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '7009219',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/1099590/000156276220000435/meli-20191231x10ka.htm',
#      'description': '10-K/A',
#      'type': '10-K/A'},
#     {'sequence': '2',
#      'size': '7686',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000435/meli-20191231xex23_1.htm',
#      'description': 'EX-23.1',
#      'type': 'EX-23.1'},
#     {'sequence': '3',
#      'size': '41607',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000435/meli-20191231xex31_1.htm',
#      'description': 'EX-31.1',
#      'type': 'EX-31.1'},
#     {'sequence': '4',
#      'size': '29472',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000435/meli-20191231xex31_2.htm',
#      'description': 'EX-31.2',
#      'type': 'EX-31.2'},
#     {'sequence': '5',
#      'size': '11334',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000435/meli-20191231xex32_1.htm',
#      'description': 'EX-32.1',
#      'type': 'EX-32.1'},
#     {'sequence': '6',
#      'size': '11810',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000435/meli-20191231xex32_2.htm',
#      'description': 'EX-32.2',
#      'type': 'EX-32.2'},
#     {'sequence': '7',
#      'size': '23772',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000435/meli-20191231xex23_1g001.jpg',
#      'description': 'GRAPHIC',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '32788410',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000435/0001562762-20-000435.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2019-12-31',
#    'entities': [{'fiscalYearEnd': '1231',
#      'act': '34',
#      'cik': '1099590',
#      'fileNo': '001-33647',
#      'irsNo': '980212790',
#      'companyName': 'MERCADOLIBRE INC (Filer)',
#      'type': '10-K/A',
#      'sic': '7389 Services-Business Services, NEC',
#      'filmNo': '201412793'}],
#    'id': '8bf18da81891a75c1f376463e06d0c62',
#    'seriesAndClassesContractsInformation': [],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000435/0001562762-20-000435-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '8',
#      'size': '124254',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000435/meli-20191231.xsd',
#      'description': 'EX-101.SCH',
#      'type': 'EX-101.SCH'},
#     {'sequence': '9',
#      'size': '170746',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000435/meli-20191231_cal.xml',
#      'description': 'EX-101.CAL',
#      'type': 'EX-101.CAL'},
#     {'sequence': '10',
#      'size': '485143',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000435/meli-20191231_def.xml',
#      'description': 'EX-101.DEF',
#      'type': 'EX-101.DEF'},
#     {'sequence': '11',
#      'size': '909030',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000435/meli-20191231_lab.xml',
#      'description': 'EX-101.LAB',
#      'type': 'EX-101.LAB'},
#     {'sequence': '12',
#      'size': '834594',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000435/meli-20191231_pre.xml',
#      'description': 'EX-101.PRE',
#      'type': 'EX-101.PRE'},
#     {'sequence': '13',
#      'size': '9867779',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000435/meli-20191231x10ka_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]},
#   {'id': '7997290eb3be59b371beb8b7ff9adb03',
#    'accessionNo': '0001562762-20-000055',
#    'cik': '1099590',
#    'ticker': 'MELI',
#    'companyName': 'MERCADOLIBRE INC',
#    'companyNameLong': 'MERCADOLIBRE INC (Filer)',
#    'formType': '10-K',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'filedAt': '2020-02-14T17:14:03-05:00',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000055/0001562762-20-000055.txt',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/1099590/0001562762-20-000055-index.htm',
#    'linkToXbrl': '',
#    'linkToFilingDetails': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/1099590/000156276220000055/meli-20191231x10k.htm',
#    'entities': [{'companyName': 'MERCADOLIBRE INC (Filer)',
#      'cik': '1099590',
#      'irsNo': '980212790',
#      'fiscalYearEnd': '1231',
#      'type': '10-K',
#      'act': '34',
#      'fileNo': '001-33647',
#      'filmNo': '20621876',
#      'sic': '7389 Services-Business Services, NEC'}],
#    'documentFormatFiles': [{'sequence': '1',
#      'description': '10-K',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/1099590/000156276220000055/meli-20191231x10k.htm',
#      'type': '10-K',
#      'size': '11328257'},
#     {'sequence': '2',
#      'description': 'EX-4.03',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000055/meli-20191231xex4_03.htm',
#      'type': 'EX-4.03',
#      'size': '21547'},
#     {'sequence': '3',
#      'description': 'EX-10.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000055/meli-20191231xex10_01.htm',
#      'type': 'EX-10.01',
#      'size': '262670'},
#     {'sequence': '4',
#      'description': 'EX-21.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000055/meli-20191231xex21_01.htm',
#      'type': 'EX-21.01',
#      'size': '39814'},
#     {'sequence': '5',
#      'description': 'EX-23.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000055/meli-20191231xex23_01.htm',
#      'type': 'EX-23.01',
#      'size': '3632'},
#     {'sequence': '6',
#      'description': 'EX-23.02',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000055/meli-20191231xex23_02.htm',
#      'type': 'EX-23.02',
#      'size': '3513'},
#     {'sequence': '7',
#      'description': 'EX-31.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000055/meli-20191231xex31_01.htm',
#      'type': 'EX-31.01',
#      'size': '40891'},
#     {'sequence': '8',
#      'description': 'EX-31.02',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000055/meli-20191231xex31_02.htm',
#      'type': 'EX-31.02',
#      'size': '40609'},
#     {'sequence': '9',
#      'description': 'EX-32.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000055/meli-20191231xex32_01.htm',
#      'type': 'EX-32.01',
#      'size': '11094'},
#     {'sequence': '10',
#      'description': 'EX-32.02',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000055/meli-20191231xex32_02.htm',
#      'type': 'EX-32.02',
#      'size': '11571'},
#     {'sequence': '11',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000055/meli-20191231x10kg001.jpg',
#      'type': 'GRAPHIC',
#      'size': '47942'},
#     {'sequence': '\xa0',
#      'description': 'Complete submission text file',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000055/0001562762-20-000055.txt',
#      'type': '\xa0',
#      'size': '37713725'}],
#    'dataFiles': [{'sequence': '12',
#      'description': 'EX-101.SCH',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000055/meli-20191231.xsd',
#      'type': 'EX-101.SCH',
#      'size': '123244'},
#     {'sequence': '13',
#      'description': 'EX-101.CAL',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000055/meli-20191231_cal.xml',
#      'type': 'EX-101.CAL',
#      'size': '170222'},
#     {'sequence': '14',
#      'description': 'EX-101.DEF',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000055/meli-20191231_def.xml',
#      'type': 'EX-101.DEF',
#      'size': '484223'},
#     {'sequence': '15',
#      'description': 'EX-101.LAB',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000055/meli-20191231_lab.xml',
#      'type': 'EX-101.LAB',
#      'size': '907369'},
#     {'sequence': '16',
#      'description': 'EX-101.PRE',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000055/meli-20191231_pre.xml',
#      'type': 'EX-101.PRE',
#      'size': '831277'},
#     {'sequence': '106',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276220000055/meli-20191231x10k_htm.xml',
#      'type': 'XML',
#      'size': '9864890'}],
#    'seriesAndClassesContractsInformation': [],
#    'periodOfReport': '2019-12-31'},
#   {'id': 'e6d9201eadc9314521b864dcaf775f96',
#    'accessionNo': '0001562762-19-000047',
#    'cik': '1099590',
#    'ticker': 'MELI',
#    'companyName': 'MERCADOLIBRE INC',
#    'companyNameLong': 'MERCADOLIBRE INC (Filer)',
#    'formType': '10-K',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'filedAt': '2019-02-28T09:18:56-05:00',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276219000047/0001562762-19-000047.txt',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/1099590/0001562762-19-000047-index.htm',
#    'linkToXbrl': '',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276219000047/meli-20181231x10k.htm',
#    'entities': [{'companyName': 'MERCADOLIBRE INC (Filer)',
#      'cik': '1099590',
#      'irsNo': '980212790',
#      'type': '10-K',
#      'act': '34',
#      'fileNo': '001-33647',
#      'filmNo': '19640742',
#      'sic': '7389 Services-Business Services, NEC'}],
#    'documentFormatFiles': [{'sequence': '1',
#      'description': '10-K',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276219000047/meli-20181231x10k.htm',
#      'type': '10-K',
#      'size': '6123755'},
#     {'sequence': '2',
#      'description': 'EX-21.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276219000047/meli-20181231xex21_01.htm',
#      'type': 'EX-21.01',
#      'size': '38206'},
#     {'sequence': '3',
#      'description': 'EX-23.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276219000047/meli-20181231xex23_01.htm',
#      'type': 'EX-23.01',
#      'size': '3794'},
#     {'sequence': '4',
#      'description': 'EX-23.02',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276219000047/meli-20181231xex23_02.htm',
#      'type': 'EX-23.02',
#      'size': '3594'},
#     {'sequence': '5',
#      'description': 'EX-31.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276219000047/meli-20181231xex31_01.htm',
#      'type': 'EX-31.01',
#      'size': '41053'},
#     {'sequence': '6',
#      'description': 'EX-31.02',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276219000047/meli-20181231xex31_02.htm',
#      'type': 'EX-31.02',
#      'size': '40771'},
#     {'sequence': '7',
#      'description': 'EX-32.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276219000047/meli-20181231xex32_01.htm',
#      'type': 'EX-32.01',
#      'size': '11337'},
#     {'sequence': '8',
#      'description': 'EX-32.02',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276219000047/meli-20181231xex32_02.htm',
#      'type': 'EX-32.02',
#      'size': '11813'},
#     {'sequence': '9',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276219000047/meli-20181231x10kg001.jpg',
#      'type': 'GRAPHIC',
#      'size': '30030'},
#     {'sequence': '\xa0',
#      'description': 'Complete submission text file',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276219000047/0001562762-19-000047.txt',
#      'type': '\xa0',
#      'size': '22093392'}],
#    'dataFiles': [{'sequence': '10',
#      'description': 'EX-101.INS',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276219000047/meli-20181231.xml',
#      'type': 'EX-101.INS',
#      'size': '5586935'},
#     {'sequence': '11',
#      'description': 'EX-101.SCH',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276219000047/meli-20181231.xsd',
#      'type': 'EX-101.SCH',
#      'size': '123591'},
#     {'sequence': '12',
#      'description': 'EX-101.CAL',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276219000047/meli-20181231_cal.xml',
#      'type': 'EX-101.CAL',
#      'size': '139704'},
#     {'sequence': '13',
#      'description': 'EX-101.DEF',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276219000047/meli-20181231_def.xml',
#      'type': 'EX-101.DEF',
#      'size': '477670'},
#     {'sequence': '14',
#      'description': 'EX-101.LAB',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276219000047/meli-20181231_lab.xml',
#      'type': 'EX-101.LAB',
#      'size': '838086'},
#     {'sequence': '15',
#      'description': 'EX-101.PRE',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276219000047/meli-20181231_pre.xml',
#      'type': 'EX-101.PRE',
#      'size': '782880'}],
#    'seriesAndClassesContractsInformation': [],
#    'periodOfReport': '2018-12-31'},
#   {'id': 'b8e1db2580780774e5bb38c064ee6c15',
#    'accessionNo': '0001562762-18-000040',
#    'cik': '1099590',
#    'ticker': 'MELI',
#    'companyName': 'MERCADOLIBRE INC',
#    'companyNameLong': 'MERCADOLIBRE INC (Filer)',
#    'formType': '10-K',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'filedAt': '2018-02-23T16:15:54-05:00',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276218000040/0001562762-18-000040.txt',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/1099590/0001562762-18-000040-index.htm',
#    'linkToXbrl': '',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276218000040/meli-20171231x10k.htm',
#    'entities': [{'companyName': 'MERCADOLIBRE INC (Filer)',
#      'cik': '1099590',
#      'irsNo': '980212790',
#      'type': '10-K',
#      'act': '34',
#      'fileNo': '001-33647',
#      'filmNo': '18636712',
#      'sic': '7389 Services-Business Services, NEC'}],
#    'documentFormatFiles': [{'sequence': '1',
#      'description': '10-K',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276218000040/meli-20171231x10k.htm',
#      'type': '10-K',
#      'size': '6046736'},
#     {'sequence': '2',
#      'description': 'EX-21.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276218000040/meli-20171231xex21_01.htm',
#      'type': 'EX-21.01',
#      'size': '33571'},
#     {'sequence': '3',
#      'description': 'EX-23.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276218000040/meli-20171231xex23_01.htm',
#      'type': 'EX-23.01',
#      'size': '3390'},
#     {'sequence': '4',
#      'description': 'EX-23.02',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276218000040/meli-20171231xex23_02.htm',
#      'type': 'EX-23.02',
#      'size': '3352'},
#     {'sequence': '5',
#      'description': 'EX-31.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276218000040/meli-20171231xex31_01.htm',
#      'type': 'EX-31.01',
#      'size': '41109'},
#     {'sequence': '6',
#      'description': 'EX-31.02',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276218000040/meli-20171231xex31_02.htm',
#      'type': 'EX-31.02',
#      'size': '40830'},
#     {'sequence': '7',
#      'description': 'EX-32.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276218000040/meli-20171231xex32_01.htm',
#      'type': 'EX-32.01',
#      'size': '11313'},
#     {'sequence': '8',
#      'description': 'EX-32.02',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276218000040/meli-20171231xex32_02.htm',
#      'type': 'EX-32.02',
#      'size': '9321'},
#     {'sequence': '9',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276218000040/meli-20171231x10kg001.jpg',
#      'type': 'GRAPHIC',
#      'size': '32125'},
#     {'sequence': '\xa0',
#      'description': 'Complete submission text file',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276218000040/0001562762-18-000040.txt',
#      'type': '\xa0',
#      'size': '20528000'}],
#    'dataFiles': [{'sequence': '10',
#      'description': 'EX-101.INS',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276218000040/meli-20171231.xml',
#      'type': 'EX-101.INS',
#      'size': '5038255'},
#     {'sequence': '11',
#      'description': 'EX-101.SCH',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276218000040/meli-20171231.xsd',
#      'type': 'EX-101.SCH',
#      'size': '112927'},
#     {'sequence': '12',
#      'description': 'EX-101.CAL',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276218000040/meli-20171231_cal.xml',
#      'type': 'EX-101.CAL',
#      'size': '134927'},
#     {'sequence': '13',
#      'description': 'EX-101.DEF',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276218000040/meli-20171231_def.xml',
#      'type': 'EX-101.DEF',
#      'size': '408891'},
#     {'sequence': '14',
#      'description': 'EX-101.LAB',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276218000040/meli-20171231_lab.xml',
#      'type': 'EX-101.LAB',
#      'size': '772952'},
#     {'sequence': '15',
#      'description': 'EX-101.PRE',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276218000040/meli-20171231_pre.xml',
#      'type': 'EX-101.PRE',
#      'size': '696499'}],
#    'seriesAndClassesContractsInformation': [],
#    'periodOfReport': '2017-12-31'},
#   {'id': '4c19d18e87678edebb324eb239248661',
#    'accessionNo': '0001562762-17-000024',
#    'cik': '1099590',
#    'ticker': 'MELI',
#    'companyName': 'MERCADOLIBRE INC',
#    'companyNameLong': 'MERCADOLIBRE INC (Filer)',
#    'formType': '10-K',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'filedAt': '2017-02-24T16:31:03-05:00',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276217000024/0001562762-17-000024.txt',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/1099590/0001562762-17-000024-index.htm',
#    'linkToXbrl': '',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276217000024/meli-20161231x10k.htm',
#    'entities': [{'companyName': 'MERCADOLIBRE INC (Filer)',
#      'cik': '1099590',
#      'irsNo': '980212790',
#      'type': '10-K',
#      'act': '34',
#      'fileNo': '001-33647',
#      'filmNo': '17637794',
#      'sic': '7389 Services-Business Services, NEC'}],
#    'documentFormatFiles': [{'sequence': '1',
#      'description': '10-K',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276217000024/meli-20161231x10k.htm',
#      'type': '10-K',
#      'size': '6712502'},
#     {'sequence': '2',
#      'description': 'EX-21.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276217000024/meli-20161231xex21_01.htm',
#      'type': 'EX-21.01',
#      'size': '27866'},
#     {'sequence': '3',
#      'description': 'EX-23.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276217000024/meli-20161231xex23_01.htm',
#      'type': 'EX-23.01',
#      'size': '3546'},
#     {'sequence': '4',
#      'description': 'EX-23.02',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276217000024/meli-20161231xex23_02.htm',
#      'type': 'EX-23.02',
#      'size': '3324'},
#     {'sequence': '5',
#      'description': 'EX-31.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276217000024/meli-20161231xex31_01.htm',
#      'type': 'EX-31.01',
#      'size': '40864'},
#     {'sequence': '6',
#      'description': 'EX-31.02',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276217000024/meli-20161231xex31_02.htm',
#      'type': 'EX-31.02',
#      'size': '40586'},
#     {'sequence': '7',
#      'description': 'EX-32.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276217000024/meli-20161231xex32_01.htm',
#      'type': 'EX-32.01',
#      'size': '10988'},
#     {'sequence': '8',
#      'description': 'EX-32.02',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276217000024/meli-20161231xex32_02.htm',
#      'type': 'EX-32.02',
#      'size': '9077'},
#     {'sequence': '9',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276217000024/meli-20161231x10kg001.jpg',
#      'type': 'GRAPHIC',
#      'size': '51611'},
#     {'sequence': '\xa0',
#      'description': 'Complete submission text file',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276217000024/0001562762-17-000024.txt',
#      'type': '\xa0',
#      'size': '22107751'}],
#    'dataFiles': [{'sequence': '10',
#      'description': 'EX-101.INS',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276217000024/meli-20161231.xml',
#      'type': 'EX-101.INS',
#      'size': '5451574'},
#     {'sequence': '11',
#      'description': 'EX-101.SCH',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276217000024/meli-20161231.xsd',
#      'type': 'EX-101.SCH',
#      'size': '111750'},
#     {'sequence': '12',
#      'description': 'EX-101.CAL',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276217000024/meli-20161231_cal.xml',
#      'type': 'EX-101.CAL',
#      'size': '139797'},
#     {'sequence': '13',
#      'description': 'EX-101.DEF',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276217000024/meli-20161231_def.xml',
#      'type': 'EX-101.DEF',
#      'size': '413414'},
#     {'sequence': '14',
#      'description': 'EX-101.LAB',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276217000024/meli-20161231_lab.xml',
#      'type': 'EX-101.LAB',
#      'size': '758801'},
#     {'sequence': '15',
#      'description': 'EX-101.PRE',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276217000024/meli-20161231_pre.xml',
#      'type': 'EX-101.PRE',
#      'size': '704442'}],
#    'seriesAndClassesContractsInformation': [],
#    'periodOfReport': '2016-12-31'},
#   {'id': '3ba82b7e3bd5afd58af0504f1ccfd69c',
#    'accessionNo': '0001562762-16-000352',
#    'cik': '1099590',
#    'ticker': 'MELI',
#    'companyName': 'MERCADOLIBRE INC',
#    'companyNameLong': 'MERCADOLIBRE INC (Filer)',
#    'formType': '10-K',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'filedAt': '2016-02-26T17:44:12-05:00',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276216000352/0001562762-16-000352.txt',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/1099590/0001562762-16-000352-index.htm',
#    'linkToXbrl': '',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276216000352/meli-20151231x10k.htm',
#    'entities': [{'companyName': 'MERCADOLIBRE INC (Filer)',
#      'cik': '1099590',
#      'irsNo': '980212790',
#      'type': '10-K',
#      'act': '34',
#      'fileNo': '001-33647',
#      'filmNo': '161463781',
#      'sic': '7389 Services-Business Services, NEC'}],
#    'documentFormatFiles': [{'sequence': '1',
#      'description': '10-K',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276216000352/meli-20151231x10k.htm',
#      'type': '10-K',
#      'size': '7023243'},
#     {'sequence': '2',
#      'description': 'EX-21.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276216000352/meli-20151231ex210136767.htm',
#      'type': 'EX-21.01',
#      'size': '26722'},
#     {'sequence': '3',
#      'description': 'EX-23.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276216000352/meli-20151231ex2301aa88d.htm',
#      'type': 'EX-23.01',
#      'size': '3384'},
#     {'sequence': '4',
#      'description': 'EX-31.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276216000352/meli-20151231ex3101343a8.htm',
#      'type': 'EX-31.01',
#      'size': '36133'},
#     {'sequence': '5',
#      'description': 'EX-31.02',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276216000352/meli-20151231ex3102117c9.htm',
#      'type': 'EX-31.02',
#      'size': '36013'},
#     {'sequence': '6',
#      'description': 'EX-32.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276216000352/meli-20151231ex320173971.htm',
#      'type': 'EX-32.01',
#      'size': '10352'},
#     {'sequence': '7',
#      'description': 'EX-32.02',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276216000352/meli-20151231ex320254082.htm',
#      'type': 'EX-32.02',
#      'size': '8586'},
#     {'sequence': '8',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276216000352/meli-20151231x10kg001.jpg',
#      'type': 'GRAPHIC',
#      'size': '23193'},
#     {'sequence': '\xa0',
#      'description': 'Complete submission text file',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276216000352/0001562762-16-000352.txt',
#      'type': '\xa0',
#      'size': '22506380'}],
#    'dataFiles': [{'sequence': '9',
#      'description': 'EX-101.INS',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276216000352/meli-20151231.xml',
#      'type': 'EX-101.INS',
#      'size': '5450222'},
#     {'sequence': '10',
#      'description': 'EX-101.SCH',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276216000352/meli-20151231.xsd',
#      'type': 'EX-101.SCH',
#      'size': '112627'},
#     {'sequence': '11',
#      'description': 'EX-101.CAL',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276216000352/meli-20151231_cal.xml',
#      'type': 'EX-101.CAL',
#      'size': '141505'},
#     {'sequence': '12',
#      'description': 'EX-101.DEF',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276216000352/meli-20151231_def.xml',
#      'type': 'EX-101.DEF',
#      'size': '432654'},
#     {'sequence': '13',
#      'description': 'EX-101.LAB',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276216000352/meli-20151231_lab.xml',
#      'type': 'EX-101.LAB',
#      'size': '752533'},
#     {'sequence': '14',
#      'description': 'EX-101.PRE',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000156276216000352/meli-20151231_pre.xml',
#      'type': 'EX-101.PRE',
#      'size': '724670'}],
#    'seriesAndClassesContractsInformation': [],
#    'periodOfReport': '2015-12-31'},
#   {'id': '65cd1eea62e6345bd7566078ef33be52',
#    'accessionNo': '0001193125-15-069727',
#    'cik': '1099590',
#    'ticker': 'MELI',
#    'companyName': 'MERCADOLIBRE INC',
#    'companyNameLong': 'MERCADOLIBRE INC (Filer)',
#    'formType': '10-K',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'filedAt': '2015-02-27T16:11:23-05:00',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312515069727/0001193125-15-069727.txt',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/1099590/0001193125-15-069727-index.htm',
#    'linkToXbrl': '',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312515069727/d861783d10k.htm',
#    'entities': [{'companyName': 'MERCADOLIBRE INC (Filer)',
#      'cik': '1099590',
#      'irsNo': '980212790',
#      'type': '10-K',
#      'act': '34',
#      'fileNo': '001-33647',
#      'filmNo': '15658788',
#      'sic': '7389 Services-Business Services, NEC'}],
#    'documentFormatFiles': [{'sequence': '1',
#      'description': '10-K',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312515069727/d861783d10k.htm',
#      'type': '10-K',
#      'size': '2164847'},
#     {'sequence': '2',
#      'description': 'EX-21.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312515069727/d861783dex2101.htm',
#      'type': 'EX-21.01',
#      'size': '15672'},
#     {'sequence': '3',
#      'description': 'EX-23.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312515069727/d861783dex2301.htm',
#      'type': 'EX-23.01',
#      'size': '1626'},
#     {'sequence': '4',
#      'description': 'EX-31.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312515069727/d861783dex3101.htm',
#      'type': 'EX-31.01',
#      'size': '9576'},
#     {'sequence': '5',
#      'description': 'EX-31.02',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312515069727/d861783dex3102.htm',
#      'type': 'EX-31.02',
#      'size': '9665'},
#     {'sequence': '6',
#      'description': 'EX-32.01',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312515069727/d861783dex3201.htm',
#      'type': 'EX-32.01',
#      'size': '4518'},
#     {'sequence': '7',
#      'description': 'EX-32.02',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312515069727/d861783dex3202.htm',
#      'type': 'EX-32.02',
#      'size': '4530'},
#     {'sequence': '14',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312515069727/g861783g67d09.jpg',
#      'type': 'GRAPHIC',
#      'size': '33314'},
#     {'sequence': '\xa0',
#      'description': 'Complete submission text file',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312515069727/0001193125-15-069727.txt',
#      'type': '\xa0',
#      'size': '16264163'}],
#    'dataFiles': [{'sequence': '8',
#      'description': 'XBRL INSTANCE DOCUMENT',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312515069727/meli-20141231.xml',
#      'type': 'EX-101.INS',
#      'size': '2357864'},
#     {'sequence': '9',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312515069727/meli-20141231.xsd',
#      'type': 'EX-101.SCH',
#      'size': '125517'},
#     {'sequence': '10',
#      'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312515069727/meli-20141231_cal.xml',
#      'type': 'EX-101.CAL',
#      'size': '158247'},
#     {'sequence': '11',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312515069727/meli-20141231_def.xml',
#      'type': 'EX-101.DEF',
#      'size': '488802'},
#     {'sequence': '12',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312515069727/meli-20141231_lab.xml',
#      'type': 'EX-101.LAB',
#      'size': '914974'},
#     {'sequence': '13',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312515069727/meli-20141231_pre.xml',
#      'type': 'EX-101.PRE',
#      'size': '699778'}],
#    'seriesAndClassesContractsInformation': [],
#    'periodOfReport': '2014-12-31'},
#   {'ticker': 'MELI',
#    'formType': '10-K',
#    'accessionNo': '0001193125-14-078151',
#    'cik': '1099590',
#    'companyNameLong': 'MERCADOLIBRE INC (Filer)',
#    'companyName': 'MERCADOLIBRE INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312514078151/d639270d10k.htm',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312514078151/0001193125-14-078151.txt',
#    'filedAt': '2014-02-28T19:20:13-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '2113945',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312514078151/d639270d10k.htm',
#      'description': 'FORM 10-K',
#      'type': '10-K'},
#     {'sequence': '2',
#      'size': '14800',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312514078151/d639270dex2101.htm',
#      'description': 'EX-21.01',
#      'type': 'EX-21.01'},
#     {'sequence': '3',
#      'size': '1614',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312514078151/d639270dex2301.htm',
#      'description': 'EX-23.01',
#      'type': 'EX-23.01'},
#     {'sequence': '4',
#      'size': '9987',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312514078151/d639270dex3101.htm',
#      'description': 'EX-31.01',
#      'type': 'EX-31.01'},
#     {'sequence': '5',
#      'size': '10336',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312514078151/d639270dex3102.htm',
#      'description': 'EX-31.02',
#      'type': 'EX-31.02'},
#     {'sequence': '6',
#      'size': '4419',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312514078151/d639270dex3201.htm',
#      'description': 'EX-32.01',
#      'type': 'EX-32.01'},
#     {'sequence': '7',
#      'size': '4431',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312514078151/d639270dex3202.htm',
#      'description': 'EX-32.02',
#      'type': 'EX-32.02'},
#     {'sequence': '14',
#      'size': '59457',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312514078151/g639270tx_pg040.jpg',
#      'description': 'GRAPHIC',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '14127326',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312514078151/0001193125-14-078151.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2013-12-31',
#    'entities': [{'act': '34',
#      'cik': '1099590',
#      'fileNo': '001-33647',
#      'irsNo': '000000000',
#      'companyName': 'MERCADOLIBRE INC (Filer)',
#      'type': '10-K',
#      'sic': '7389 Services-Business Services, NEC',
#      'filmNo': '14657652'}],
#    'id': '6628b360a56b6186451edc03c38548b7',
#    'seriesAndClassesContractsInformation': [],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/1099590/0001193125-14-078151-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '8',
#      'size': '2288809',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312514078151/meli-20131231.xml',
#      'description': 'XBRL INSTANCE DOCUMENT',
#      'type': 'EX-101.INS'},
#     {'sequence': '9',
#      'size': '116339',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312514078151/meli-20131231.xsd',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA',
#      'type': 'EX-101.SCH'},
#     {'sequence': '10',
#      'size': '131623',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312514078151/meli-20131231_cal.xml',
#      'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE',
#      'type': 'EX-101.CAL'},
#     {'sequence': '11',
#      'size': '364188',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312514078151/meli-20131231_def.xml',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE',
#      'type': 'EX-101.DEF'},
#     {'sequence': '12',
#      'size': '833514',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312514078151/meli-20131231_lab.xml',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE',
#      'type': 'EX-101.LAB'},
#     {'sequence': '13',
#      'size': '608872',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312514078151/meli-20131231_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE',
#      'type': 'EX-101.PRE'}]},
#   {'ticker': 'MELI',
#    'formType': '10-K',
#    'accessionNo': '0001193125-13-081326',
#    'cik': '1099590',
#    'companyNameLong': 'MERCADOLIBRE INC (Filer)',
#    'companyName': 'MERCADOLIBRE INC',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312513081326/d466750d10k.htm',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312513081326/0001193125-13-081326.txt',
#    'filedAt': '2013-02-27T22:00:32-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '2353048',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312513081326/d466750d10k.htm',
#      'description': 'FORM 10-K',
#      'type': '10-K'},
#     {'sequence': '2',
#      'size': '14679',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312513081326/d466750dex2101.htm',
#      'description': 'EX-21.01',
#      'type': 'EX-21.01'},
#     {'sequence': '3',
#      'size': '2349',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1099590/000119312513081326/d466750dex2301.htm',
#      'description': 'EX-23.01',
# ...
#      'size': '3663'},
#     {'sequence': '19',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/gzou35kfceum000012.jpg',
#      'type': 'GRAPHIC',
#      'size': '8350'},
#     {'sequence': '20',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/gzou35kfceum000004.jpg',
#      'type': 'GRAPHIC',
#      'size': '20854'},
#     {'sequence': '21',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/gzou35kfceum000008.jpg',
#      'type': 'GRAPHIC',
#      'size': '10929'},
#     {'sequence': '22',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/gzou35kfceum000001.jpg',
#      'type': 'GRAPHIC',
#      'size': '17827'},
#     {'sequence': '23',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/gzou35kfceum000003.jpg',
#      'type': 'GRAPHIC',
#      'size': '18645'},
#     {'sequence': '24',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/gzou35kfceum000016.jpg',
#      'type': 'GRAPHIC',
#      'size': '11580'},
#     {'sequence': '25',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/gzou35kfceum000009.jpg',
#      'type': 'GRAPHIC',
#      'size': '9320'},
#     {'sequence': '26',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/gzou35kfceum000002.jpg',
#      'type': 'GRAPHIC',
#      'size': '631'},
#     {'sequence': '27',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/gzou35kfceum000006.jpg',
#      'type': 'GRAPHIC',
#      'size': '10036'},
#     {'sequence': '28',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/gzou35kfceum000011.jpg',
#      'type': 'GRAPHIC',
#      'size': '631'},
#     {'sequence': '29',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/gzou35kfceum000017.jpg',
#      'type': 'GRAPHIC',
#      'size': '8485'},
#     {'sequence': '30',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/gzou35kfceum000018.jpg',
#      'type': 'GRAPHIC',
#      'size': '42411'},
#     {'sequence': '31',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/gzou35kfceum000013.jpg',
#      'type': 'GRAPHIC',
#      'size': '10883'},
#     {'sequence': '\xa0',
#      'description': 'Complete submission text file',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/0001564590-20-010071.txt',
#      'type': '\xa0',
#      'size': '13240001'}],
#    'dataFiles': [{'sequence': '32',
#      'description': 'XBRL INSTANCE DOCUMENT',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/ubx-20191231.xml',
#      'type': 'EX-101.INS',
#      'size': '2806223'},
#     {'sequence': '33',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/ubx-20191231.xsd',
#      'type': 'EX-101.SCH',
#      'size': '80625'},
#     {'sequence': '34',
#      'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/ubx-20191231_cal.xml',
#      'type': 'EX-101.CAL',
#      'size': '62757'},
#     {'sequence': '35',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/ubx-20191231_def.xml',
#      'type': 'EX-101.DEF',
#      'size': '285475'},
#     {'sequence': '36',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/ubx-20191231_lab.xml',
#      'type': 'EX-101.LAB',
#      'size': '624808'},
#     {'sequence': '37',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459020010071/ubx-20191231_pre.xml',
#      'type': 'EX-101.PRE',
#      'size': '503276'}],
#    'seriesAndClassesContractsInformation': [],
#    'periodOfReport': '2019-12-31'},
#   {'id': '372bc2b7c5df327417732458aa785161',
#    'accessionNo': '0001564590-19-006397',
#    'cik': '1463361',
#    'ticker': 'UBX',
#    'companyName': 'Unity Biotechnology, Inc.',
#    'companyNameLong': 'Unity Biotechnology, Inc. (Filer)',
#    'formType': '10-K',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'filedAt': '2019-03-06T08:06:52-05:00',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/0001564590-19-006397.txt',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/1463361/0001564590-19-006397-index.htm',
#    'linkToXbrl': '',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/ubx-10k_20181231.htm',
#    'entities': [{'companyName': 'Unity Biotechnology, Inc. (Filer)',
#      'cik': '1463361',
#      'irsNo': '264726035',
#      'stateOfIncorporation': 'DE',
#      'fiscalYearEnd': '1231',
#      'type': '10-K',
#      'act': '34',
#      'fileNo': '001-38470',
#      'filmNo': '19661298',
#      'sic': '2834 Pharmaceutical Preparations'}],
#    'documentFormatFiles': [{'sequence': '1',
#      'description': '10-K',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/ubx-10k_20181231.htm',
#      'type': '10-K',
#      'size': '3836553'},
#     {'sequence': '2',
#      'description': 'EX-10.6',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/ubx-ex106_800.htm',
#      'type': 'EX-10.6',
#      'size': '25859'},
#     {'sequence': '3',
#      'description': 'EX-10.22',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/ubx-ex1022_427.htm',
#      'type': 'EX-10.22',
#      'size': '331987'},
#     {'sequence': '4',
#      'description': 'EX-10.23',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/ubx-ex1023_254.htm',
#      'type': 'EX-10.23',
#      'size': '1011365'},
#     {'sequence': '5',
#      'description': 'EX-23.1',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/ubx-ex231_860.htm',
#      'type': 'EX-23.1',
#      'size': '2225'},
#     {'sequence': '6',
#      'description': 'EX-31.1',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/ubx-ex311_252.htm',
#      'type': 'EX-31.1',
#      'size': '18116'},
#     {'sequence': '7',
#      'description': 'EX-31.2',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/ubx-ex312_250.htm',
#      'type': 'EX-31.2',
#      'size': '18099'},
#     {'sequence': '8',
#      'description': 'EX-32.1',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/ubx-ex321_251.htm',
#      'type': 'EX-32.1',
#      'size': '14653'},
#     {'sequence': '9',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000018.jpg',
#      'type': 'GRAPHIC',
#      'size': '6438'},
#     {'sequence': '10',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000020.jpg',
#      'type': 'GRAPHIC',
#      'size': '19927'},
#     {'sequence': '11',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000002.jpg',
#      'type': 'GRAPHIC',
#      'size': '631'},
#     {'sequence': '12',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gzdbt4joaqjd000004.jpg',
#      'type': 'GRAPHIC',
#      'size': '70995'},
#     {'sequence': '13',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000017.jpg',
#      'type': 'GRAPHIC',
#      'size': '631'},
#     {'sequence': '14',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000025.jpg',
#      'type': 'GRAPHIC',
#      'size': '30091'},
#     {'sequence': '15',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000019.jpg',
#      'type': 'GRAPHIC',
#      'size': '8826'},
#     {'sequence': '16',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000005.jpg',
#      'type': 'GRAPHIC',
#      'size': '149061'},
#     {'sequence': '17',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000007.jpg',
#      'type': 'GRAPHIC',
#      'size': '116574'},
#     {'sequence': '18',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000004.jpg',
#      'type': 'GRAPHIC',
#      'size': '140412'},
#     {'sequence': '19',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000006.jpg',
#      'type': 'GRAPHIC',
#      'size': '631'},
#     {'sequence': '20',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000001.jpg',
#      'type': 'GRAPHIC',
#      'size': '21146'},
#     {'sequence': '21',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000008.jpg',
#      'type': 'GRAPHIC',
#      'size': '631'},
#     {'sequence': '22',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gijg3mykzm0a000001.jpg',
#      'type': 'GRAPHIC',
#      'size': '9121'},
#     {'sequence': '23',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gzdbt4joaqjd000001.jpg',
#      'type': 'GRAPHIC',
#      'size': '62155'},
#     {'sequence': '24',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000003.jpg',
#      'type': 'GRAPHIC',
#      'size': '631'},
#     {'sequence': '25',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000012.jpg',
#      'type': 'GRAPHIC',
#      'size': '6856'},
#     {'sequence': '26',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gzdbt4joaqjd000002.jpg',
#      'type': 'GRAPHIC',
#      'size': '56087'},
#     {'sequence': '27',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000014.jpg',
#      'type': 'GRAPHIC',
#      'size': '631'},
#     {'sequence': '28',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gzdbt4joaqjd000003.jpg',
#      'type': 'GRAPHIC',
#      'size': '15662'},
#     {'sequence': '29',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000023.jpg',
#      'type': 'GRAPHIC',
#      'size': '631'},
#     {'sequence': '30',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gzdbt4joaqjd000006.jpg',
#      'type': 'GRAPHIC',
#      'size': '36603'},
#     {'sequence': '31',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gzdbt4joaqjd000005.jpg',
#      'type': 'GRAPHIC',
#      'size': '38683'},
#     {'sequence': '32',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000009.jpg',
#      'type': 'GRAPHIC',
#      'size': '8363'},
#     {'sequence': '33',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000024.jpg',
#      'type': 'GRAPHIC',
#      'size': '14178'},
#     {'sequence': '34',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000016.jpg',
#      'type': 'GRAPHIC',
#      'size': '11039'},
#     {'sequence': '35',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000015.jpg',
#      'type': 'GRAPHIC',
#      'size': '25697'},
#     {'sequence': '36',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000021.jpg',
#      'type': 'GRAPHIC',
#      'size': '27212'},
#     {'sequence': '37',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000022.jpg',
#      'type': 'GRAPHIC',
#      'size': '631'},
#     {'sequence': '38',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000010.jpg',
#      'type': 'GRAPHIC',
#      'size': '8306'},
#     {'sequence': '39',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000013.jpg',
#      'type': 'GRAPHIC',
#      'size': '18052'},
#     {'sequence': '40',
#      'description': 'GRAPHIC',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/gqwwhpzdbs0v000011.jpg',
#      'type': 'GRAPHIC',
#      'size': '7810'},
#     {'sequence': '\xa0',
#      'description': 'Complete submission text file',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/0001564590-19-006397.txt',
#      'type': '\xa0',
#      'size': '15158979'}],
#    'dataFiles': [{'sequence': '41',
#      'description': 'XBRL INSTANCE DOCUMENT',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/ubx-20181231.xml',
#      'type': 'EX-101.INS',
#      'size': '2797816'},
#     {'sequence': '42',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/ubx-20181231.xsd',
#      'type': 'EX-101.SCH',
#      'size': '80396'},
#     {'sequence': '43',
#      'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/ubx-20181231_cal.xml',
#      'type': 'EX-101.CAL',
#      'size': '62212'},
#     {'sequence': '44',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/ubx-20181231_def.xml',
#      'type': 'EX-101.DEF',
#      'size': '278095'},
#     {'sequence': '45',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/ubx-20181231_lab.xml',
#      'type': 'EX-101.LAB',
#      'size': '594082'},
#     {'sequence': '46',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1463361/000156459019006397/ubx-20181231_pre.xml',
#      'type': 'EX-101.PRE',
#      'size': '488380'}],
#    'seriesAndClassesContractsInformation': [],
#    'periodOfReport': '2018-12-31'}]]

# %%
len(full_query)
# Out:
# 53

# %%
len(accession_numbers)
# Out:
# 489

# %%
import time

# get XBRL-JSON for a given accession number
def get_xbrl_json(accession_no, retry = 0):
    
    """
    This function was taken from the github user mentioned in the beginning of this notebook. This function \
    takes an accession number for a filing and returns the data from the filing in json format.
    """
    
    request_url = xbrl_converter_api_endpoint + "?accession-no=" + accession_no + "&token=" + '88140c3a554da7220ba7453a5e1ea2221c5f1e0e42c3293bbe75857245774e2e'

    # linear backoff in case API fails with "too many requests" error
    try:
      response_tmp = requests.get(request_url)
      xbrl_json = json.loads(response_tmp.text)
    except:
      if retry > 5:
        raise Exception('API error')
      
      # wait 500 milliseconds on error and retry
      time.sleep(0.5) 
      return get_xbrl_json(accession_no, retry + 1)

    return xbrl_json

# %%
list_xbrl = []
counter = 0

# loop through each accession number and append the json data into a list
for acc_no in accession_numbers:
    if counter % 10 == 0:
        print(f"processing {counter}")
    list_xbrl.append(get_xbrl_json(acc_no))
    counter += 1
# Out:
# processing 0
# processing 10
# processing 20
# processing 30
# processing 40
# processing 50
# processing 60
# processing 70
# processing 80
# processing 90
# processing 100
# processing 110
# processing 120
# processing 130
# processing 140
# processing 150
# processing 160
# processing 170
# processing 180
# processing 190
# processing 200
# processing 210
# processing 220
# processing 230
# processing 240
# processing 250
# processing 260
# processing 270
# processing 280
# processing 290
# processing 300
# processing 310
# processing 320
# processing 330
# processing 340
# processing 350
# processing 360
# processing 370
# processing 380
# processing 390
# processing 400
# processing 410
# processing 420
# processing 430
# processing 440
# processing 450
# processing 460
# processing 470
# processing 480

# %%
cleaned_list_xbrl = []

# create a cleaned list for xbrl data because some filings have no xbrl data to parse
for xbrl in list_xbrl:
    if 'message' in xbrl.keys():
        pass
    else:
        cleaned_list_xbrl.append(xbrl)

# %%
len(list_xbrl)
# Out:
# 489

# %%
len(cleaned_list_xbrl)
# Out:
# 291

# %%
# write list to binary file
def write_list(a_list):
    
    """
    This function takes in a list and dumps the contents of the list into a pickled file.
    """
    
    # store list in binary file so 'wb' mode
    with open('./data/listfile_mystocks', 'wb') as fp:
        pickle.dump(a_list, fp)
        print('Done writing list into a binary file')
    fp.close()

# %%
write_list(cleaned_list_xbrl)
# Out:
# Done writing list into a binary file

# %%
# Read list to memory
def read_list(path):
    
    """
    This function reads a pickled file for a list into memory.
    """
    
    # for reading also binary mode is important
    with open(path, 'rb') as fp:
        n_list = pickle.load(fp)
    fp.close()
    return n_list

# %%
# list of names
loaded_xbrl = read_list('./data/listfile_mystocks')
len(loaded_xbrl)
# Out:
# 291

# %%
# create a stock mapper instance so I can pull ticker symbols for stocks
mapper = StockMapper()
map_stock = mapper.cik_to_tickers

# %%
def get_sector(ticker):
    
    """
    This function takes the ticker for a public company as a string and returns the company's sector.
    """
    
    print(ticker)
    tick = yf.Ticker(ticker)
    return tick.get_info()['sector']

# %%
def stock_10yr(ticker, year, count=0):
    
    """
    This function takes the ticker for a public company and a start year to begin tracking the company. 
    The function returns the overall 10 year return to shareholders as a percentage.
    """
    
    print(ticker, year)
    tick = yf.Ticker(ticker)
    try:
        start_price = tick.history(start=f'{year}-01-01')['Close'][0]
    except:
        if count > 5:
            raise Exception('yfinance not doing its job')
        time.sleep(5)
        return stock_10yr(ticker, year, count+1)
    end_year = str(int(year)+10)
    try:
        final_price = tick.history(start=f'{end_year}-01-01')['Close'][0]
    except: 
        if count > 5:
            raise Exception('yfinance not doing its job')
        time.sleep(5) 
        return stock_10yr(ticker, year, count+1)
        
    perc_return = round(((final_price - start_price) / start_price), 5)*100
    return perc_return

# %%
def spy_10yr(year):
    
    """
    This function takes in a year and returns the S&P500 10 year return from that year.
    """
    
    spy = yf.Ticker('SPY')
    start_price = spy.history(start=f'{year}-01-01')['Close'][0]
    end_year = str(int(year)+10)
    final_price = spy.history(start=f'{end_year}-01-01')['Close'][0]
    perc_return = round(((final_price - start_price) / start_price), 5)*100
    return perc_return

# %%
def financials(list_of_xbrl):
    
    """
    This function takes in a list of json data for various filings and returns a dataframe of all \
    relevant financial statistics for every company from the list. The function combinese dataframes \
    for the balance sheet, income statement, and cash flow statement. This function also creates a column \ 
    for the stock ticker symbol.
    """
    
    balance_full_list = []

    for xbrl in list_of_xbrl:
        try:
            balance_full_list.append(get_balance_sheet(xbrl))
        except:
            continue   
    balance_full_df = pd.concat(balance_full_list)
    # pull relevant columns for analysis
    balance_df_final = balance_full_df[['year', 'CIK', 'AssetsCurrent', 'LiabilitiesCurrent']]
    balance_df_final.dropna(inplace=True)
    
    income_full_list = []

    for xbrl in list_of_xbrl:
        try:
            income_full_list.append(get_income_statement(xbrl))
        except:
            continue   
    income_full_df = pd.concat(income_full_list)
    # pull relevant columns for analysis
    income_df_final = income_full_df[['OperatingIncomeLoss', 'NetIncomeLoss', 'CIK', 'year']]
    income_df_final.dropna(inplace=True)
    
    cashflow_full_list = []

    for xbrl in list_of_xbrl:
        try:
            cashflow_full_list.append(get_cash_flow_statement(xbrl))
        except:
            continue   
    cashflow_full_df = pd.concat(cashflow_full_list)
    # pull relevant columns for analysis
    cashflow_df_final = cashflow_full_df[['year', 'CIK', 'NetCashProvidedByUsedInOperatingActivities', 'NetCashProvidedByUsedInInvestingActivities', 'NetCashProvidedByUsedInFinancingActivities', 'CashAndCashEquivalentsPeriodIncreaseDecrease']]
    final_financials = balance_df_final.merge(cashflow_df_final, how='inner', on=['CIK', 'year']).merge(income_df_final, how='inner', on=['CIK', 'year'])
    final_financials['ticker'] = final_financials['CIK'].map(map_stock)
    final_financials.dropna(inplace=True)
    
    final_financials['ticker'] = final_financials['ticker'].map(str).str.slice(2, -2)
    final_financials['ticker'] = final_financials['ticker'].apply(lambda row: row if len(str(row)) <= 4 else 0)
    final_financials = final_financials[final_financials['ticker'] != 0]
    
    return final_financials

# %%
df_final = financials(loaded_xbrl)

# %%
df_final
# Out:
#     year         CIK AssetsCurrent LiabilitiesCurrent  \
# 22  2016  0001512673    1001425000          577464000
# 45  2016  0001595974     391577000          218437000
# 46  2015  0001595974     365707000          250163000
# 47  2014  0001595974     237977000          154402000
# 51  2013  0001141391   10950000000         6032000000
# 52  2012  0001141391    9357000000         4906000000
# 53  2011  0001141391    7741000000         4217000000
# 73  2010  0001053507    1404174000          542195000
# 77  2014  0001403161    9562000000         6006000000
# 78  2013  0001403161    7822000000         4335000000
# 82  2016  0000937556     507227000          220366000
# 83  2016  0000937556     507227000          220366000
# 84  2016  0000937556     507227000          220366000
# 85  2016  0000937556     507227000          220366000
# 86  2016  0000937556     299142000          132633000
# 87  2016  0000937556     299142000          132633000
# 88  2016  0000937556     299142000          132633000
# 89  2016  0000937556     299142000          132633000
#
#    NetCashProvidedByUsedInOperatingActivities  \
# 22                                   23131000
# 45                                   60120000
# 46                                   76856000
# 47                                    6645000
# 51                                 4135000000
# 52                                 2948000000
# 53                                 2684000000
# 73                                 1020977000
# 77                                 7205000000
# 78                                 3022000000
# 82                                  416842000
# 83                                  416842000
# 84                                  114209000
# 85                                  114209000
# 86                                  416842000
# 87                                  416842000
# 88                                  114209000
# 89                                  114209000
#
#    NetCashProvidedByUsedInInvestingActivities  \
# 22                                 -122733000
# 45                                  -37116000
# 46                                  -72861000
# 47                                  -23123000
# 51                                   -4000000
# 52                                -2839000000
# 53                                 -748000000
# 73                                -1300902000
# 77                                 -941000000
# 78                                -1164000000
# 82                                  -25114000
# 83                                  -25114000
# 84                                  -54594000
# 85                                  -54594000
# 86                                  -25114000
# 87                                  -25114000
# 88                                  -54594000
# 89                                  -54594000
#
#    NetCashProvidedByUsedInFinancingActivities  \
# 22                                   90741000
# 45                                   10077000
# 46                                   15468000
# 47                                   83794000
# 51                                -2629000000
# 52                                -1798000000
# 53                                -1215000000
# 73                                  910330000
# 77                                -6478000000
# 78                                -1746000000
# 82                                 -216624000
# 83                                 -216624000
# 84                                  -59070000
# 85                                  -59070000
# 86                                 -216624000
# 87                                 -216624000
# 88                                  -59070000
# 89                                  -59070000
#
#    CashAndCashEquivalentsPeriodIncreaseDecrease OperatingIncomeLoss  \
# 22                                     -9299000          -170453000
# 45                                     32924000           -24897000
# 46                                     19303000            -5598000
# 47                                     67240000           -18778000
# 51                                   1547000000           920000000
# 52                                  -1682000000           899000000
# 53                                    667000000           -10000000
# 73                                    636670000           203441000
# 77                                   -215000000          7697000000
# 78                                    112000000          7239000000
# 82                                    173653000           310400000
# 83                                    173653000            36892000
# 84                                     -2136000           310400000
# 85                                     -2136000            36892000
# 86                                    173653000           310400000
# 87                                    173653000            36892000
# 88                                     -2136000           310400000
# 89                                     -2136000            36892000
#
#    NetIncomeLoss ticker
# 22    -171590000     SQ
# 45     -18053000   MGNI
# 46        422000   MGNI
# 47     -18673000   MGNI
# 51     623000000     MA
# 52     605000000     MA
# 53      19000000     MA
# 73      83514000    AMT
# 77    5438000000      V
# 78    4980000000      V
# 82     215293000   MASI
# 83      24101000   MASI
# 84     215293000   MASI
# 85      24101000   MASI
# 86     215293000   MASI
# 87      24101000   MASI
# 88     215293000   MASI
# 89      24101000   MASI

# %%
# create a list of years that data was extracted from
yrs_list = [2009, 2010, 2011, 2012]

# %%
# create a list of S&P 500 returns for each year
spy_returns = [spy_10yr(year) for year in yrs_list]

# %%
# zip the two lists together into a dictionary
spy_dict = dict(zip(yrs_list, spy_returns))

# %%
spy_dict
# Out:
# {2009: 230.065,
#  2010: 250.11899999999997,
#  2011: 254.2,
#  2012: 353.76500000000004}

# %%
# create a new column that has the S&P 500 10 year returns based on the year of financial statistics
df['SPY'] = df['year'].map(spy_dict)

# %%
df.head()
# Out:
#    year      CIK  AssetsCurrent  LiabilitiesCurrent  \
# 0  2009  1140859     9953753000          9479610000
# 1  2009   829224     2035800000          1581000000
# 2  2009   796343     2473624000           844553000
# 3  2009   875045     2480595000           714942000
# 4  2009   100885     3680000000          2682000000
#
#    NetCashProvidedByUsedInOperatingActivities  \
# 0                                   783763000
# 1                                  1389000000
# 2                                  1117772000
# 3                                  1074898000
# 4                                  3234000000
#
#    NetCashProvidedByUsedInInvestingActivities  \
# 0                               -1.483490e+08
# 1                               -4.211000e+08
# 2                               -1.497096e+09
# 3                               -3.950310e+08
# 4                               -2.175000e+09
#
#    NetCashProvidedByUsedInFinancingActivities  \
# 0                                  -504160000
# 1                                  -642200000
# 2                                   477658000
# 3                                  -724151000
# 4                                  -458000000
#
#    CashAndCashEquivalentsPeriodIncreaseDecrease  OperatingIncomeLoss  \
# 0                                     131254000            883749000
# 1                                     330000000            562000000
# 2                                     113037000            690513000
# 3                                     -44284000           1295427000
# 4                                     601000000           3392000000
#
#    NetIncomeLoss ticker      SPY
# 0      503397000    ABC  230.065
# 1      390800000   SBUX  230.065
# 2      386508000   ADBE  230.065
# 3      970132000   BIIB  230.065
# 4     1898000000    UNP  230.065

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519 entries, 0 to 518
# Data columns (total 12 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    519 non-null    int64
#  1   year                                          519 non-null    int64
#  2   CIK                                           519 non-null    int64
#  3   AssetsCurrent                                 519 non-null    int64
#  4   LiabilitiesCurrent                            519 non-null    int64
#  5   NetCashProvidedByUsedInOperatingActivities    519 non-null    int64
#  6   NetCashProvidedByUsedInInvestingActivities    519 non-null    float64
#  7   NetCashProvidedByUsedInFinancingActivities    519 non-null    int64
#  8   CashAndCashEquivalentsPeriodIncreaseDecrease  519 non-null    int64
#  9   OperatingIncomeLoss                           519 non-null    int64
#  10  NetIncomeLoss                                 519 non-null    int64
#  11  ticker                                        519 non-null    object
# dtypes: float64(1), int64(10), object(1)
# memory usage: 48.8+ KB

# %%
df.groupby('year').count()
# Out:
#       CIK  AssetsCurrent  LiabilitiesCurrent  \
# year
# 2009   10             10                  10
# 2010   17             17                  17
# 2011  119            119                 119
# 2012   64             64                  64
#
#       NetCashProvidedByUsedInOperatingActivities  \
# year
# 2009                                          10
# 2010                                          17
# 2011                                         119
# 2012                                          64
#
#       NetCashProvidedByUsedInInvestingActivities  \
# year
# 2009                                          10
# 2010                                          17
# 2011                                         119
# 2012                                          64
#
#       NetCashProvidedByUsedInFinancingActivities  \
# year
# 2009                                          10
# 2010                                          17
# 2011                                         119
# 2012                                          64
#
#       CashAndCashEquivalentsPeriodIncreaseDecrease  OperatingIncomeLoss  \
# year
# 2009                                            10                   10
# 2010                                            17                   17
# 2011                                           119                  119
# 2012                                            64                   64
#
#       NetIncomeLoss  ticker
# year
# 2009             10      10
# 2010             17      17
# 2011            119     119
# 2012             64      64

# %%
# drop duplicate rows as there were some cases with over 10 duplicate rows
df.drop_duplicates(inplace=True)

# %%
df.head(20)
# Out:
#     year      CIK  AssetsCurrent  LiabilitiesCurrent  \
# 0   2009  1140859     9953753000          9479610000
# 1   2009   829224     2035800000          1581000000
# 2   2009   796343     2473624000           844553000
# 3   2009   875045     2480595000           714942000
# 4   2009   100885     3680000000          2682000000
# 5   2009  1022079     1679425000          1059212000
# 6   2009   823768     3010000000          2901000000
# 7   2009  1306830     2856000000          1607000000
# 8   2009     7332      564501000           536416000
# 9   2009  1018963     1997600000           624600000
# 10  2010   103379     2629356000          1092583000
# 11  2010    40704     3480000000          3769100000
# 12  2010   731802      875192000          1166079000
# 13  2010   755001      117100000           126900000
# 21  2010   876167      483858000           237676000
# 22  2010  1133421     9904000000          8386000000
# 23  2011    91440     1765500000           881100000
# 24  2011    91440     1530700000           583800000
# 25  2010    48898     1226100000           445000000
# 26  2010     6201     6838000000          8780000000
#
#     NetCashProvidedByUsedInOperatingActivities  \
# 0                                    783763000
# 1                                   1389000000
# 2                                   1117772000
# 3                                   1074898000
# 4                                   3234000000
# 5                                    997418000
# 6                                   2362000000
# 7                                    596000000
# 8                                   1359376000
# 9                                    218500000
# 10                                   973485000
# 11                                  2181200000
# 12                                   726476000
# 13                                    25900000
# 21                                    96201000
# 22                                  2453000000
# 23                                   140400000
# 24                                   140400000
# 25                                   266200000
# 26                                  1241000000
#
#     NetCashProvidedByUsedInInvestingActivities  \
# 0                                -1.483490e+08
# 1                                -4.211000e+08
# 2                                -1.497096e+09
# 3                                -3.950310e+08
# 4                                -2.175000e+09
# 5                                -1.959040e+08
# 6                                -1.250000e+09
# 7                                 3.100000e+07
# 8                                -1.780604e+09
# 9                                -4.537000e+08
# 10                               -3.168760e+08
# 11                               -7.212000e+08
# 12                               -5.427020e+08
# 13                               -4.960000e+07
# 21                               -4.516300e+07
# 22                               -7.610000e+08
# 23                               -3.030000e+08
# 24                               -3.030000e+08
# 25                               -5.470000e+07
# 26                               -2.030000e+09
#
#     NetCashProvidedByUsedInFinancingActivities  \
# 0                                   -504160000
# 1                                   -642200000
# 2                                    477658000
# 3                                   -724151000
# 4                                   -458000000
# 5                                   -521204000
# 6                                   -457000000
# 7                                   -112000000
# 8                                    238135000
# 9                                    474100000
# 10                                  -319343000
# 11                                 -1503800000
# 12                                  -163025000
# 13                                    24900000
# 21                                    68164000
# 22                                 -1266000000
# 23                                    34800000
# 24                                    34800000
# 25                                    45500000
# 26                                   804000000
#
#     CashAndCashEquivalentsPeriodIncreaseDecrease  OperatingIncomeLoss  \
# 0                                      131254000            883749000
# 1                                      330000000            562000000
# 2                                      113037000            690513000
# 3                                      -44284000           1295427000
# 4                                      601000000           3392000000
# 5                                      280310000           1359111000
# 6                                      660000000           1887000000
# 7                                      578000000            290000000
# 8                                     -183093000            -34966000
# 9                                      238900000             92700000
# 10                                     349705000            736817000
# 11                                     -76600000           2606100000
# 12                                      20749000            489436000
# 13                                       1200000             28000000
# 21                                     110686000             67670000
# 22                                     426000000            788000000
# 23                                    -127200000            331400000
# 24                                    -127200000            331400000
# 25                                     262200000            367800000
# 26                                      15000000            308000000
#
#     NetIncomeLoss ticker      SPY
# 0       503397000    ABC  230.065
# 1       390800000   SBUX  230.065
# 2       386508000   ADBE  230.065
# 3       970132000   BIIB  230.065
# 4      1898000000    UNP  230.065
# 5       729111000    DGX  230.065
# 6       994000000     WM  230.065
# 7       488000000     CE  230.065
# 8       -35650000    SWN  230.065
# 9        31700000    ATI  230.065
# 10      461271000    VFC  250.119
# 11     1530500000    GIS  250.119
# 12      205839000    ATO  250.119
# 13        9600000    UTL  250.119
# 21       48571000   PRGS  250.119
# 22      376000000    NOC  250.119
# 23      186500000    SNA  254.200
# 24      186500000    SNA  254.200
# 25      217200000   HUBB  250.119
# 26     -471000000    AAL  250.119

# %% [markdown]
# Given the yfinance package is not the most reliable, I needed to subset my data before making repeated API calls. By doing this, if the code failed to pull relevant data from Yahoo Finance, I only lost a small portion of time. Each df listed below is a subset of the final dataframe that I created

# %%
df1 = df.iloc[:5]
df2 = df.iloc[5:25]

# %%
df3 = df.iloc[25:40]
df5 = df.iloc[40:55]
df6 = df.iloc[55:70]
df7 = df.iloc[70:85]

# %%
df8 = df.iloc[100:150]
df9 = df.iloc[150:]

# %%
df4 = df.iloc[85:100]

# %% [markdown]
# Next, I created multiple lists of tuples that contain both a stock's ticker symbol as well as the year. By doing this, I can loop through the list to create a list of all the 10 year returns for these stocks. I initially tried to do this in a function, but the yfinance package took significantly too long.

# %%
tick_year2 = list(zip(df2['ticker'], df2['year']))

# %%
tick_year3 = list(zip(df3['ticker'], df3['year']))

# %%
tick_year4 = list(zip(df4['ticker'], df4['year']))

# %%
tick_year5 = list(zip(df5['ticker'], df5['year']))
tick_year6 = list(zip(df6['ticker'], df6['year']))
tick_year7 = list(zip(df7['ticker'], df7['year']))

# %%
tick_year8 = list(zip(df8['ticker'], df8['year']))

# %%
tick_year9 = list(zip(df9['ticker'], df9['year']))

# %%
returnslist2 = [stock_10yr(ticker, year) for (ticker, year) in tick_year]

# %%
returnslist3 = []

for ticker, year in tick_year3:
    returnslist3.append(stock_10yr(ticker, year))
# Out:
# CHD 2010
# OMC 2010
# HUBG 2010
# IART 2010
# WW 2011
# CRM 2011
# POLY 2011
# MOS 2011
# MLKN 2011
# TECH 2011
# SCHN 2011
# PSMT 2011
# ASYS 2011
# BEN 2011
# SPH 2011

# %%
returnslist4 = []

for ticker, year in tick_year4:
    returnslist4.append(stock_10yr(ticker, year))
# Out:
# TBI 2011
# TBI 2011
# ABG 2011
# ABG 2011
# MGTI 2011
# MGTI 2011
# SIGA 2011
# SIGA 2011
# AUTO 2011
# AUTO 2011
# PRFT 2011
# PRFT 2011
# PDCE 2011
# PDCE 2011
# RNWK 2011
# RNWK 2011
# FSLR 2011
# FSLR 2011
# VHC 2011
# VHC 2011
# VHC 2011
# VHC 2011
# MDRX 2011
# MDRX 2011
# NC 2011
# NC 2011
# HCCI 2011
# HCCI 2011
# CXDO 2011
# CXDO 2011

# %%
returnslist5 = []

for ticker, year in tick_year5:
    returnslist5.append(stock_10yr(ticker, year))
# Out:
# MATW 2011
# SANM 2011
# SIF 2011
# KNWN 2011
# BECN 2011
# FRPH 2011
# HPQ 2011
# CBAT 2011
# CIEN 2011
# MFCO 2011
# RGCO 2011
# IESC 2011
# PGLO 2011
# JOUT 2011
# EMKR 2011

# %%
returnslist6 = []

for ticker, year in tick_year6:
    returnslist6.append(stock_10yr(ticker, year))
# Out:
# DYSL 2011
# GSTC 2011
# - GSTC: No data found for this date range, symbol may be delisted
# GSTC 2011
# - GSTC: No data found for this date range, symbol may be delisted
# GSTC 2011
# - GSTC: No data found for this date range, symbol may be delisted
# GSTC 2011
# GSTC 2011
# - GSTC: No data found for this date range, symbol may be delisted
# GSTC 2011
# JOB 2011
# BDL 2011
# OPXS 2011
# GSTX 2011
# BUUZ 2011
# PLAB 2011
# STLY 2011
# PBSV 2011
# INLX 2011
# GFGY 2011
# SNX 2011
# LEVI 2011
# DHX 2011

# %%
returnslist7 = []

for ticker, year in tick_year7:
    returnslist7.append(stock_10yr(ticker, year))
# Out:
# VG 2011
# MAR 2011
# HAL 2011
# MA 2011
# MPAD 2011
# CCI 2011
# CE 2011
# AMKR 2011
# INTC 2011
# EAF 2011
# FYBR 2011
# CTXS 2011
# KO 2011
# GPK 2011
# ANSS 2011

# %%
returnslist8 = []

for ticker, year in tick_year8:
    returnslist8.append(stock_10yr(ticker, year))
# Out:
# CEMI 2011
# VSEC 2011
# PXLW 2011
# LXRX 2011
# BYD 2011
# ACU 2011
# GERN 2011
# TREX 2011
# PRPH 2011
# HHS 2011
# NLS 2011
# EGLE 2011
# STRL 2011
# CUTR 2011
# BBSI 2011
# MODV 2011
# STXS 2011
# CLSN 2011
# PESI 2011
# EBIX 2011
# DXYN 2011
# IMUC 2011
# AMNL 2011
# LOAN 2011
# ADYX 2011
# CLTH 2011
# UCIX 2011
# UCIX 2011
# PAR 2011
# USIO 2011
# URBN 2012
# GAXY 2011
# SCVL 2012
# NNAX 2011
# CONN 2012
# LTUM 2011
# HQI 2011
# LAKE 2012
# BUDZ 2011
# AGSS 2011
# CAMP 2012
# MICR 2011
# NVEC 2012
# PPIH 2012
# LBSR 2012
# ZWS 2012
# PBH 2012
# SODI 2012
# DBRM 2012
# ESTE 2012

# %%
returnslist9 = []

for ticker, year in tick_year9:
    returnslist9.append(stock_10yr(ticker, year))
# Out:
# TESS 2012
# MOD 2012
# RNVA 2012
# QMCO 2012
# NXTP 2012
# DAKT 2012
# CIDM 2012
# UUU 2012
# PFIE 2012
# MEI 2012
# FRHC 2012
# ELTP 2012
# AMWD 2012
# MICS 2012
# TTEC 2011
# MOS 2012
# TENX 2012
# RGP 2012
# GBLX 2012
# GPN 2012
# OTEX 2012
# STX 2012
# PG 2012
# NAUH 2012
# AIT 2012
# VSYM 2011
# LTRX 2012
# HAIN 2012
# TAYD 2012
# TECH 2012
# AEHR 2012
# SCSC 2012
# AOSL 2012
# CTIB 2011
# PSTV 2011
# SANW 2012
# DNAX 2011
# EVI 2012
# MPAA 2012
# WESC 2012
# ATRX 2011
# SGLY 2012
# SCHN 2012
# SRRE 2011
# IVZ 2011
# CUII 2012
# NNVC 2012
# HMLA 2012
# SANM 2012
# SBUX 2012
# TDG 2012
# BECN 2012
# SPH 2012
# MATW 2012
# EACO 2012
# GRYN 2012
# MFCO 2012
# CIEN 2012

# %% [markdown]
# With all of the 10 year returns now generated, I can insert a new column into each subset of data containing the 10 year return percentage.

# %%
df1.insert(loc=11, column='10yrReturns', value=returns)

# %%
df2.insert(loc=11, column='10yrReturns', value=returnslist2)

# %%
df3.insert(loc=11, column='10yrReturns', value=returnslist3)

# %%
df4.insert(loc=11, column='10yrReturns', value=returnslist4)

# %%
df5.insert(loc=11, column='10yrReturns', value=returnslist5)

# %%
df6.insert(loc=11, column='10yrReturns', value=returnslist6)

# %%
df7.insert(loc=11, column='10yrReturns', value=returnslist7)

# %%
df8.insert(loc=11, column='10yrReturns', value=returnslist8)

# %%
df9.insert(loc=11, column='10yrReturns', value=returnslist9)

# %%
# saving off all dataframes as CSV files to ensure I won't need to run this code again
df1.to_csv('./data/df1')

# %%
df2.to_csv('./data/df2')

# %%
df3.to_csv('./data/df3')

# %%
df4.to_csv('./data/df4')

# %%
df5.to_csv('./data/df5')

# %%
df6.to_csv('./data/df6')

# %%
df7.to_csv('./data/df7')

# %%
df8.to_csv('./data/df8')

# %%
df9.to_csv('./data/df9')

# %%
df.to_csv('./data/baseline_df')

# %%
# combine all of the dataframes together 
full_df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9], axis=0, ignore_index=True)

# %%
# create our target column that is simply a Boolean for whether or not the stock's 10 year return outperformed the 
# S&P 500 10 year return
full_df['marketBeat?'] = (full_df['10yrReturns'] > full_df['SPY']).astype(int)

# %%
full_df
# Out:
#      year      CIK  AssetsCurrent  LiabilitiesCurrent  \
# 0    2009  1140859     9953753000          9479610000
# 1    2009   829224     2035800000          1581000000
# 2    2009   796343     2473624000           844553000
# 3    2009   875045     2480595000           714942000
# 4    2009   100885     3680000000          2682000000
# 5    2009  1022079     1679425000          1059212000
# 6    2009   823768     3010000000          2901000000
# 7    2009  1306830     2856000000          1607000000
# 8    2009     7332      564501000           536416000
# 9    2009  1018963     1997600000           624600000
# 10   2010   103379     2629356000          1092583000
# 11   2010    40704     3480000000          3769100000
# 12   2010   731802      875192000          1166079000
# 13   2010   755001      117100000           126900000
# 14   2010   876167      483858000           237676000
# 15   2010  1133421     9904000000          8386000000
# 16   2011    91440     1765500000           881100000
# 17   2011    91440     1530700000           583800000
# 18   2010    48898     1226100000           445000000
# 19   2010     6201     6838000000          8780000000
# 20   2010   931148      545884000           220643000
# 21   2010   931148      545884000           220643000
# 22   2010   350894      683719000           127600000
# 23   2010  1048477      504260000            83844000
# 24   2010   821189     2527446000          2220099000
# 25   2010   313927      649481000           447092000
# 26   2010    29989    10194100000         11023100000
# 27   2010   940942      329160000           167418000
# 28   2010   917520      444849000           200032000
# 29   2011   105319      190442000           539135000
# 30   2011  1108524     1074924000          1276466000
# 31   2011   914025      617720000            93602000
# 32   2011  1285785     6684900000          1928500000
# 33   2011    66382      478100000           272200000
# 34   2011   842023      230417000            18188000
# 35   2011   912603      653999000           233313000
# 36   2011  1041803      292777000           218227000
# 37   2011   720500      174851000            80794000
# 38   2011    38777     7616768000          1312064000
# 39   2011  1005210      297822000           151514000
# 40   2011   768899      280615000           112289000
# 41   2011  1144980      792500000           636300000
# 42   2011  1001601        4204000              786000
# 43   2011  1010086       52978703             6922777
# 44   2011  1023364       22324000             8291000
# 45   2011  1085869       74988000            23512000
# 46   2011    77877      173050000           195046000
# 47   2011  1046327      249563000            88776000
# 48   2011  1274494     2613261000           973724000
# 49   2011  1082324       74470000             6356000
# 50   2011  1082324       74470000             6356000
# 51   2011  1124804      680649000           510757000
# 52   2011   789933     1375100000           891200000
# 53   2011  1403431       44474000            28932000
# 54   2011  1075736       21552000            13171000
# 55   2011    63296      369846000           161741000
# 56   2011   897723     2629246000          1265885000
# 57   2011    90168       39658000            14434000
# 58   2011  1074828        1662909             4865384
# 59   2011  1124941      678865000           268034000
# 60   2011   844059       34694000            18232000
# 61   2011    47217    51021000000         50442000000
# 62   2011  1117171      197228929           302600446
# 63   2011   936395     1332838000           453493000
# 64   2011   716688        2297142              639032
# 65   2011  1069533       31004245            31027444
# 66   2011  1048268      161124000            98287000
# 67   2011  1492617              4               16760
# 68   2011   788329      176445000            65000000
# 69   2011   808326       91351000            67058000
# 70   2011    30831       15644122             6207295
# 71   2011  1502152          21942               31625
# 72   2011    40570        7108000             6121000
# 73   2011    12040        8293000             6473000
# 74   2011  1397016        8011000             1795000
# 75   2011  1497649         714818              255087
# 76   2011  1174891          12998               71513
# 77   2011   810136      305207000            95901000
# 78   2011   797465       62522000            16456000
# 79   2011  1304161        9607782             2523637
# 80   2011  1081745             68               81832
# 81   2011  1181749       27542361            13680184
# 82   2011  1177394     2438415000          1372253000
# 83   2011    94845     1743221000           872261000
# 84   2011  1393883       83603000            83972000
# 85   2011  1272830      124770000           204955000
# 86   2011  1048286     1324000000          2558000000
# 87   2011    45012    11577000000          4121000000
# 88   2011  1141391     7741000000          4217000000
# 89   2011    65759          19016                1673
# 90   2011  1051470      599152000           402106000
# 91   2011  1306830     2703000000          1385000000
# 92   2011  1047127      996830000           642186000
# 93   2011    50863    25872000000         12028000000
# 94   2011   931148      731950000           277253000
# 95   2011    20520     1270030000          1183216000
# 96   2011   877890     1373030000          1179130000
# 97   2011    21344    25497000000         24283000000
# 98   2011  1408075     1314100000           645500000
# 99   2011  1013462      740033000           438751000
# 100  2011  1092662        8991582             2857626
# 101  2011   102752      178447000           107324000
# 102  2011  1040161       26097000            12887000
# 103  2011  1062822      285790000            21390000
# 104  2011   906553      342894000           472020000
# 105  2011     2098       46522364             8704020
# 106  2011   886744      125625000            13444000
# 107  2011  1069878      102054000           120628000
# 108  2011   868278       13195000             7853000
# 109  2011    45919      275517000           205069000
# 110  2011  1078207       58087000            38648000
# 111  2011  1322439       55890837            69121710
# 112  2011   874238      164023000            69285000
# 113  2011  1162461      106095000            17020000
# 114  2011   902791      128957000            79318000
# 115  2011  1220754      158093398           106886803
# 116  2011  1289340       34236171            40832389
# 117  2011   749647       31508485             6152424
# 118  2011   891532       51775000            40226000
# 119  2011   814549       63817000            49779000
# 120  2011    29332      100999000            34582000
# 121  2011   822411        6744454             1761289
# 122  2011     8328       10524447             3948611
# 123  2011  1080340        7264363             1501103
# 124  2011  1054274         603908              337193
# 125  2011  1411036          41599             3434145
# 126  2011  1358099         299731              427415
# 127  2011  1358099         299731              427415
# 128  2011   708821       77010000            38565000
# 129  2011  1088034        4086922             4298666
# 130  2012   912615      596992000           233466000
# 131  2011  1127993          35612              545818
# 132  2012   895447      316261000            75760000
# 133  2011  1132509            232              354845
# 134  2012  1223389      452558000            94674000
# 135  2011  1415332        1044125               21730
# 136  2011  1140102        5437131             3601059
# 137  2012   798081       73707953             9453188
# 138  2011  1393772           3356              243116
# 139  2011  1514443         372411              844992
# 140  2012   730255       39789000            23601000
# 141  2011   819689        9010271             2891593
# 142  2012   724910       26170233             1667905
# 143  2012   914122       82434000            39486000
# 144  2012  1172178         170020             4457613
# 145  2012  1439288     1018300000           467300000
# 146  2012  1295947      147035000            63923000
# 147  2012    91668       11493000             1858000
# 148  2012  1164256         626778             3848154
# 149  2012    10254       10006000             3434000
# 150  2012   927355      165763400            99983600
# 151  2012    67347      427531000           297551000
# 152  2012   931059        8294000              582000
# 153  2012   709283      281221000           210053000
# 154  2012  1372183          61056            14607206
# 155  2012   915779      229006000           109173000
# 156  2012  1173204       63393000            60436000
# 157  2012   102109       11786272             1293765
# 158  2012  1289636        8143468             1494182
# 159  2012    65270      240433000            91877000
# 160  2012   924805       41210068            20046765
# 161  2012  1053369        1497840             4549109
# 162  2012   794619      131102000            59221000
# 163  2012   923601        5277443             6291220
# 164  2011  1013880      478282000           170011000
# 165  2012  1285785     6581100000          1917700000
# 166  2012    34956        2631032             3126870
# 167  2012  1084765      228235000            61651000
# 168  2012  1165320           7249             1269516
# 169  2012  1123360     1248739000           837285000
# 170  2012  1002638      789274000           476513000
# 171  2012  1137789     6310000000          3396000000
# 172  2012    80424    21910000000         24907000000
# 173  2012  1399855       37252000            12667000
# 174  2012   109563      665762000           230169000
# 175  2011  1075857         297712             2115039
# 176  2012  1114925       21831000             9904000
# 177  2012   910406      448808000           202809000
# 178  2012    96536       20981560             7181252
# 179  2012   842023      346507000            35750000
# 180  2012  1040470       10928000             4855000
# 181  2012   918965     1031930000           498401000
# 182  2012  1387467      193781000            63919000
# 183  2011  1042187       23300969            17688994
# 184  2011  1095981       43337000             7821000
# 185  2012  1477246       17423189             1903263
# 186  2011  1419995         315667             3383600
# 187  2012    65312       10555618             2575932
# 188  2012   918251      168231000           170419000
# 189  2012  1368275         353048              119677
# 190  2011   737207        2576000             4639000
# 191  2012  1422892        9786401             8032427
# 192  2012   912603      516819000           178842000
# 193  2011  1083490        8591116            22370788
# 194  2011   914208     3834100000          2974400000
# 195  2012  1512927        1491618             1137964
# 196  2012  1379006       14589159             1779615
# 197  2012  1409624         156552             1013383
# 198  2012   897723     2326299000          1219547000
# 199  2012   829224     4199600000          2209800000
# 200  2012  1260221     1050531000           233915000
# 201  2012  1124941      630775000           295949000
# 202  2012  1005210      338280000           253715000
# 203  2012    63296      385225000           180873000
# 204  2012   784539       31201000            13815000
# 205  2012  1443388              0              612744
# 206  2012   716688        1926819              377683
# 207  2012   936395     1415690000           684970000
#
#      NetCashProvidedByUsedInOperatingActivities  \
# 0                                     783763000
# 1                                    1389000000
# 2                                    1117772000
# 3                                    1074898000
# 4                                    3234000000
# 5                                     997418000
# 6                                    2362000000
# 7                                     596000000
# 8                                    1359376000
# 9                                     218500000
# 10                                    973485000
# 11                                   2181200000
# 12                                    726476000
# 13                                     25900000
# 14                                     96201000
# 15                                   2453000000
# 16                                    140400000
# 17                                    140400000
# 18                                    266200000
# 19                                   1241000000
# 20                                    144922000
# 21                                    144922000
# 22                                    229326000
# 23                                     18746000
# 24                                   2708602000
# 25                                    428482000
# 26                                   1488000000
# 27                                     37654000
# 28                                    105571000
# 29                                    281484000
# 30                                    459081000
# 31                                    158232000
# 32                                   2426700000
# 33                                     91100000
# 34                                    127194000
# 35                                    140463000
# 36                                     75599000
# 37                                     15426000
# 38                                   1621778000
# 39                                    132786000
# 40                                     30589000
# 41                                   -181100000
# 42                                     -7635000
# 43                                     25574036
# 44                                      2204000
# 45                                     14320000
# 46                                    166834000
# 47                                      -708000
# 48                                    -33463000
# 49                                    -18252000
# 50                                    -18252000
# 51                                    268754000
# 52                                    155200000
# 53                                      4903000
# 54                                     -1648000
# 55                                     95564000
# 56                                    234908000
# 57                                     10220000
# 58                                     -1312291
# 59                                     79290000
# 60                                     20601000
# 61                                  12639000000
# 62                                     35318299
# 63                                    -90485000
# 64                                       466023
# 65                                     10683344
# 66                                    -11852000
# 67                                       -16413
# 68                                     30980000
# 69                                     -6289000
# 70                                      3766380
# 71                                       -52480
# 72                                     -2290000
# 73                                      4352000
# 74                                      1114000
# 75                                       477266
# 76                                       -52996
# 77                                    136553000
# 78                                     -7307000
# 79                                      2140273
# 80                                       -83871
# 81                                     11879586
# 82                                    219153000
# 83                                      1848000
# 84                                     64494000
# 85                                    146786000
# 86                                   1089000000
# 87                                   3684000000
# 88                                   2684000000
# 89                                         1468
# 90                                    643454000
# 91                                    638000000
# 92                                    516832000
# 93                                  20963000000
# 94                                     76597000
# 95                                   1572681000
# 96                                    679122000
# 97                                   9474000000
# 98                                    387800000
# 99                                    307661000
# 100                                     2268408
# 101                                    34260000
# 102                                     -735000
# 103                                   -87938000
# 104                                   253510000
# 105                                     2063068
# 106                                   -62392000
# 107                                    33847000
# 108                                    -2108000
# 109                                    60665000
# 110                                     4598000
# 111                                    58296117
# 112                                    20988000
# 113                                    -5168000
# 114                                    31355000
# 115                                    31038238
# 116                                   -31569278
# 117                                   -22742437
# 118                                    20759000
# 119                                    71286000
# 120                                     5054000
# 121                                    -6383742
# 122                                    -4699735
# 123                                      381297
# 124                                    -2196825
# 125                                     -280510
# 126                                      -73187
# 127                                      -73187
# 128                                    11001000
# 129                                     2404869
# 130                                   282702000
# 131                                     -162007
# 132                                    30875000
# 133                                      -21900
# 134                                    64517000
# 135                                     -487498
# 136                                     -627321
# 137                                       -4459
# 138                                     -123736
# 139                                      -65566
# 140                                    12432000
# 141                                      926488
# 142                                    12811910
# 143                                     -190000
# 144                                    -1164147
# 145                                   139300000
# 146                                    67452000
# 147                                      876000
# 148                                      -37700
# 149                                     5278000
# 150                                    21745500
# 151                                    45758000
# 152                                    -3108000
# 153                                    45660000
# 154                                    -4822423
# 155                                    20038000
# 156                                    39938000
# 157                                    -3823293
# 158                                     1604135
# 159                                    24825000
# 160                                    15278079
# 161                                     -394082
# 162                                    16053000
# 163                                     -237484
# 164                                   113799000
# 165                                  2705800000
# 166                                    -8278366
# 167                                    36370000
# 168                                      -96518
# 169                                  -173475000
# 170                                   266490000
# 171                                  3262000000
# 172                                 13284000000
# 173                                    12857000
# 174                                    90422000
# 175                                      -20580
# 176                                    -2523000
# 177                                   121960000
# 178                                    -1113720
# 179                                   126746000
# 180                                    -4875000
# 181                                    59958000
# 182                                    32881000
# 183                                      817973
# 184                                   -35323000
# 185                                       34124
# 186                                    -2885668
# 187                                       38053
# 188                                   -38488000
# 189                                     -340757
# 190                                   -16117000
# 191                                     -355667
# 192                                   244790000
# 193                                    -4875740
# 194                                   964800000
# 195                                     -344495
# 196                                    -4217986
# 197                                      103763
# 198                                   215413000
# 199                                  1750300000
# 200                                   413885000
# 201                                    85361000
# 202                                   110973000
# 203                                    82123000
# 204                                     2889000
# 205                                     -779799
# 206                                       86598
# 207                                   107089000
#
#      NetCashProvidedByUsedInInvestingActivities  \
# 0                                 -1.483490e+08
# 1                                 -4.211000e+08
# 2                                 -1.497096e+09
# 3                                 -3.950310e+08
# 4                                 -2.175000e+09
# 5                                 -1.959040e+08
# 6                                 -1.250000e+09
# 7                                  3.100000e+07
# 8                                 -1.780604e+09
# 9                                 -4.537000e+08
# 10                                -3.168760e+08
# 11                                -7.212000e+08
# 12                                -5.427020e+08
# 13                                -4.960000e+07
# 14                                -4.516300e+07
# 15                                -7.610000e+08
# 16                                -3.030000e+08
# 17                                -3.030000e+08
# 18                                -5.470000e+07
# 19                                -2.030000e+09
# 20                                -3.215520e+08
# 21                                -3.215520e+08
# 22                                -4.147500e+07
# 23                                -1.013420e+08
# 24                                -4.902774e+09
# 25                                -1.804480e+08
# 26                                -2.937000e+08
# 27                                -2.479800e+07
# 28                                -4.231600e+07
# 29                                -2.864600e+07
# 30                                -1.062554e+09
# 31                                -1.699110e+08
# 32                                -5.721000e+08
# 33                                -3.140000e+07
# 34                                -1.141850e+08
# 35                                -3.999010e+08
# 36                                -3.944500e+07
# 37                                -6.238000e+06
# 38                                 4.359130e+08
# 39                                -1.950500e+07
# 40                                -2.693800e+07
# 41                                 3.430000e+07
# 42                                 1.968000e+06
# 43                                 1.475826e+07
# 44                                 1.640000e+05
# 45                                -8.785000e+06
# 46                                -4.564010e+08
# 47                                 6.624000e+06
# 48                                -6.764570e+08
# 49                                 2.896800e+07
# 50                                 2.896800e+07
# 51                                -9.567400e+07
# 52                                -3.270000e+07
# 53                                 4.561500e+07
# 54                                -2.396000e+06
# 55                                -1.068120e+08
# 56                                -9.810500e+07
# 57                                -2.271300e+07
# 58                                -1.076330e+05
# 59                                -4.783200e+07
# 60                                -1.160300e+07
# 61                                -1.395900e+10
# 62                                -3.104556e+07
# 63                                -6.857000e+07
# 64                                -2.813020e+05
# 65                                -7.589102e+06
# 66                                 1.534300e+07
# 67                                 0.000000e+00
# 68                                -1.332300e+07
# 69                                -1.528600e+07
# 70                                -1.780194e+06
# 71                                 0.000000e+00
# 72                                -2.840000e+05
# 73                                -4.172000e+06
# 74                                -3.100000e+04
# 75                                -3.398308e+06
# 76                                 1.000000e+00
# 77                                -1.007370e+08
# 78                                -4.407000e+06
# 79                                -1.231110e+05
# 80                                -2.206100e+04
# 81                                -5.002000e+04
# 82                                -1.263880e+08
# 83                                -1.409570e+08
# 84                                -1.061400e+07
# 85                                -3.760400e+07
# 86                                -2.470000e+08
# 87                                -3.190000e+09
# 88                                -7.480000e+08
# 89                                -1.807000e+03
# 90                                -3.998650e+08
# 91                                -4.410000e+08
# 92                                -4.305340e+08
# 93                                -1.030100e+10
# 94                                -1.619660e+08
# 95                                -7.626720e+08
# 96                                -4.511810e+08
# 97                                -2.524000e+09
# 98                                -2.118000e+08
# 99                                -2.916430e+08
# 100                               -7.266800e+05
# 101                               -1.829210e+08
# 102                                1.183600e+07
# 103                                6.995500e+07
# 104                               -3.627870e+08
# 105                               -4.169552e+06
# 106                                3.213900e+07
# 107                               -9.367000e+06
# 108                               -1.340000e+05
# 109                               -1.755100e+07
# 110                               -8.520000e+05
# 111                               -1.577862e+08
# 112                               -4.270600e+07
# 113                                5.287000e+06
# 114                               -4.176000e+06
# 115                               -1.461576e+07
# 116                               -1.031749e+06
# 117                               -1.108709e+07
# 118                               -1.298500e+07
# 119                               -1.332000e+07
# 120                               -6.735000e+06
# 121                               -8.439200e+04
# 122                               -2.703870e+05
# 123                               -1.404880e+06
# 124                                7.320900e+04
# 125                                0.000000e+00
# 126                                0.000000e+00
# 127                                0.000000e+00
# 128                               -8.361000e+06
# 129                               -4.880000e+03
# 130                                5.529200e+07
# 131                                0.000000e+00
# 132                               -2.115500e+07
# 133                                0.000000e+00
# 134                               -4.386000e+06
# 135                               -2.621400e+04
# 136                               -1.286640e+05
# 137                               -4.871932e+06
# 138                                0.000000e+00
# 139                               -4.701600e+04
# 140                               -5.100000e+05
# 141                               -3.186060e+06
# 142                               -1.221962e+07
# 143                               -1.006800e+07
# 144                               -2.965600e+04
# 145                               -3.242000e+08
# 146                               -6.622060e+08
# 147                               -4.310000e+05
# 148                               -2.313880e+05
# 149                               -2.467000e+06
# 150                               -6.513700e+06
# 151                               -6.501000e+07
# 152                                3.328000e+06
# 153                               -2.197400e+07
# 154                               -3.050000e+05
# 155                               -1.875300e+07
# 156                               -1.731500e+07
# 157                                5.568700e+05
# 158                               -1.487628e+06
# 159                               -3.209700e+07
# 160                                1.362551e+08
# 161                               -6.577900e+05
# 162                               -9.918000e+06
# 163                               -1.652160e+05
# 164                               -8.693100e+07
# 165                               -1.627400e+09
# 166                               -2.611460e+05
# 167                               -2.052800e+07
# 168                                0.000000e+00
# 169                               -1.504330e+08
# 170                               -2.815390e+08
# 171                               -1.114000e+09
# 172                               -1.093000e+09
# 173                               -9.381000e+06
# 174                               -3.943400e+07
# 175                                0.000000e+00
# 176                               -6.390000e+05
# 177                               -2.706640e+08
# 178                               -1.556239e+06
# 179                               -2.166800e+07
# 180                                1.330000e+06
# 181                               -1.279000e+07
# 182                               -5.793100e+07
# 183                               -1.106907e+06
# 184                               -5.600000e+05
# 185                               -5.434840e+05
# 186                                1.064100e+04
# 187                               -6.544600e+04
# 188                               -1.591000e+06
# 189                               -4.046000e+04
# 190                                3.000000e+03
# 191                               -4.268000e+04
# 192                               -8.426600e+07
# 193                               -2.622980e+06
# 194                                3.481000e+08
# 195                               -2.455700e+04
# 196                               -5.855200e+04
# 197                               -2.602200e+04
# 198                               -7.802700e+07
# 199                               -9.740000e+08
# 200                               -8.762920e+08
# 201                               -1.570350e+08
# 202                               -2.397580e+08
# 203                               -4.527400e+07
# 204                                7.000000e+05
# 205                                0.000000e+00
# 206                               -1.923980e+05
# 207                               -1.197700e+07
#
#      NetCashProvidedByUsedInFinancingActivities  \
# 0                                    -504160000
# 1                                    -642200000
# 2                                     477658000
# 3                                    -724151000
# 4                                    -458000000
# 5                                    -521204000
# 6                                    -457000000
# 7                                    -112000000
# 8                                     238135000
# 9                                     474100000
# 10                                   -319343000
# 11                                  -1503800000
# 12                                   -163025000
# 13                                     24900000
# 14                                     68164000
# 15                                  -1266000000
# 16                                     34800000
# 17                                     34800000
# 18                                     45500000
# 19                                    804000000
# 20                                    138240000
# 21                                    138240000
# 22                                   -282436000
# 23                                      3504000
# 24                                   2303419000
# 25                                   -503724000
# 26                                   -537300000
# 27                                    -24590000
# 28                                     -1574000
# 29                                   -256812000
# 30                                     14074000
# 31                                    -55371000
# 32                                   -585000000
# 33                                    -50200000
# 34                                    -36288000
# 35                                    279951000
# 36                                    -30640000
# 37                                      2058000
# 38                                   -968185000
# 39                                   -120636000
# 40                                    -57215000
# 41                                    136900000
# 42                                       639000
# 43                                      2592581
# 44                                        22000
# 45                                     -8538000
# 46                                    243433000
# 47                                   -133542000
# 48                                    571218000
# 49                                      4131000
# 50                                      4131000
# 51                                   -143639000
# 52                                    -42000000
# 53                                     21141000
# 54                                     -1505000
# 55                                     10403000
# 56                                    -88954000
# 57                                       283000
# 58                                      1428300
# 59                                     -5045000
# 60                                     -5123000
# 61                                  -1566000000
# 62                                     -2800346
# 63                                     13202000
# 64                                      -392555
# 65                                     -1888443
# 66                                      -838000
# 67                                        14481
# 68                                     -8648000
# 69                                     17887000
# 70                                     -1745126
# 71                                        65500
# 72                                      1943000
# 73                                     -2363000
# 74                                      -599000
# 75                                      3217349
# 76                                        35000
# 77                                     54525000
# 78                                      1882000
# 79                                       -25162
# 80                                       106000
# 81                                     -9429231
# 82                                   -114443000
# 83                                     77707000
# 84                                    -41595000
# 85                                   -130138000
# 86                                  -1245000000
# 87                                    833000000
# 88                                  -1215000000
# 89                                         -258
# 90                                   -275712000
# 91                                   -253000000
# 92                                    -58877000
# 93                                 -11100000000
# 94                                     85461000
# 95                                   -735178000
# 96                                   -292614000
# 97                                  -2234000000
# 98                                    -42200000
# 99                                     -9676000
# 100                                     -667125
# 101                                   143348000
# 102                                   -12881000
# 103                                   157084000
# 104                                   142410000
# 105                                     3428433
# 106                                      386000
# 107                                   -47224000
# 108                                     -449000
# 109                                   -42178000
# 110                                      -32000
# 111                                    -4556384
# 112                                   -11352000
# 113                                     1382000
# 114                                    -8532000
# 115                                   -34455563
# 116                                    11307127
# 117                                    52836463
# 118                                     4180000
# 119                                   -55537000
# 120                                     1735000
# 121                                     7801526
# 122                                    13498318
# 123                                      859465
# 124                                      990000
# 125                                      274537
# 126                                      370420
# 127                                      370420
# 128                                    -1579000
# 129                                      300000
# 130                                  -532347000
# 131                                      175000
# 132                                      689000
# 133                                       21850
# 134                                   -64843000
# 135                                       84984
# 136                                      220000
# 137                                     4616379
# 138                                      122636
# 139                                      256290
# 140                                   -10562000
# 141                                     -344659
# 142                                          36
# 143                                    -1866000
# 144                                      249357
# 145                                    93200000
# 146                                   600434000
# 147                                        1000
# 148                                      285100
# 149                                      -84000
# 150                                    -5198400
# 151                                    18754000
# 152                                           0
# 153                                   -48353000
# 154                                     4720595
# 155                                   -26284000
# 156                                   -15528000
# 157                                     -275896
# 158                                           0
# 159                                    37899000
# 160                                  -109269699
# 161                                     -105580
# 162                                     5065000
# 163                                       -4547
# 164                                    15891000
# 165                                 -1061100000
# 166                                     9467440
# 167                                   -49109000
# 168                                       51000
# 169                                  -218186000
# 170                                   302584000
# 171                                 -3118000000
# 172                                -10410000000
# 173                                   -13534000
# 174                                   -60816000
# 175                                       41287
# 176                                     8700000
# 177                                   147423000
# 178                                      550377
# 179                                   -64625000
# 180                                     1576000
# 181                                   -42292000
# 182                                    20462000
# 183                                     -135465
# 184                                    20137000
# 185                                     5006311
# 186                                     2800423
# 187                                     -351687
# 188                                    70182000
# 189                                      695696
# 190                                    16024000
# 191                                      -28097
# 192                                  -120052000
# 193                                     5840436
# 194                                 -1322100000
# 195                                      304872
# 196                                     9327500
# 197                                           0
# 198                                  -366813000
# 199                                  -745500000
# 200                                   527186000
# 201                                   -31824000
# 202                                   113549000
# 203                                   -40971000
# 204                                    -2313000
# 205                                      668000
# 206                                     -130068
# 207                                     7940000
#
#      CashAndCashEquivalentsPeriodIncreaseDecrease  OperatingIncomeLoss  \
# 0                                       131254000            883749000
# 1                                       330000000            562000000
# 2                                       113037000            690513000
# 3                                       -44284000           1295427000
# 4                                       601000000           3392000000
# 5                                       280310000           1359111000
# 6                                       660000000           1887000000
# 7                                       578000000            290000000
# 8                                      -183093000            -34966000
# 9                                       238900000             92700000
# 10                                      349705000            736817000
# 11                                      -76600000           2606100000
# 12                                       20749000            489436000
# 13                                        1200000             28000000
# 14                                      110686000             67670000
# 15                                      426000000            788000000
# 16                                     -127200000            331400000
# 17                                     -127200000            331400000
# 18                                      262200000            367800000
# 19                                       15000000            308000000
# 20                                      -38390000            159182000
# 21                                      -38390000            158040000
# 22                                      -94585000            217533000
# 23                                      -79092000               544000
# 24                                      103102000            523319000
# 25                                     -257941000            444953000
# 26                                      701700000            439700000
# 27                                      -11719000             69882000
# 28                                       56872000             98694000
# 29                                       -5603000            390345000
# 30                                     -587014000              -391000
# 31                                      -65586000            140712000
# 32                                     1383400000           2664200000
# 33                                       13800000            123300000
# 34                                      -16526000            163055000
# 35                                       19120000             56255000
# 36                                        3471000             90880000
# 37                                       10618000             38279000
# 38                                     1074897000           2659827000
# 39                                       -7355000            143228000
# 40                                      -53842000             47834000
# 41                                       -9900000            133900000
# 42                                       -4730000             -7862000
# 43                                       42924877            -31381437
# 44                                        2390000               725000
# 45                                       -2975000             18532000
# 46                                      -46134000             39833000
# 47                                     -129685000            -37610000
# 48                                     -160070000            -68664000
# 49                                       14847000            -17376000
# 50                                       14847000             -6690000
# 51                                       28350000            136544000
# 52                                       76700000            174100000
# 53                                      -19571000              2496000
# ...
# 170                                     275607000            149360000
# 171                                    -970000000           3108000000
# 172                                    1668000000           3063000000
# 173                                     -10058000              9160000
# 174                                     -12650000            168395000
# 175                                         20707              -687802
# 176                                       5538000             -2788000
# 177                                       2378000            151528000
# 178                                      -2119582              2887081
# 179                                      39062000            166209000
# 180                                      -1947000             -4507000
# 181                                        426000            113516000
# 182                                      -4542000             16735000
# 183                                       -423351              1437702
# 184                                     -15746000            -29412000
# 185                                       4496951               619614
# 186                                        -74604             -4313761
# 187                                       -379080               808738
# 188                                      30140000            -27487000
# 189                                        313202              -305240
# 190                                        -90000            -34995000
# 191                                       -445495             -2924314
# 192                                      40401000             -1367000
# 193                                      -1596904              -825188
# 194                                      -9200000            898100000
# 195                                        -39002              -376646
# 196                                       5050962             -6081749
# 197                                         77741               -42099
# 198                                    -230670000            137490000
# 199                                      40500000           1997400000
# 200                                      64341000            699775000
# 201                                    -102822000            143672000
# 202                                     -15236000             42901000
# 203                                      -3403000             21852000
# 204                                       1200000              4322000
# 205                                       -111799             -1132465
# 206                                       -235868                 9046
# 207                                     100548000            -79846000
#
#      NetIncomeLoss ticker  10yrReturns      SPY  marketBeat?
# 0        503397000    ABC      382.872  230.065            1
# 1        390800000   SBUX     1404.256  230.065            1
# 2        386508000   ADBE      875.543  230.065            1
# 3        970132000   BIIB      528.356  230.065            1
# 4       1898000000    UNP      578.284  230.065            1
# 5        729111000    DGX       81.640  230.065            0
# 6        994000000     WM      265.080  230.065            1
# 7        488000000     CE      692.905  230.065            1
# 8        -35650000    SWN      -88.035  230.065            0
# 9         31700000    ATI       -2.913  230.065            0
# 10       461271000    VFC      630.394  250.119            1
# 11      1530500000    GIS      104.657  250.119            0
# 12       205839000    ATO      410.116  250.119            1
# 13         9600000    UTL      303.871  250.119            1
# 14        48571000   PRGS      124.804  250.119            0
# 15       376000000    NOC      770.519  250.119            1
# 16       186500000    SNA      251.883  254.200            0
# 17       186500000    SNA      251.883  254.200            0
# 18       217200000   HUBB      293.347  250.119            1
# 19      -471000000    AAL      544.512  250.119            1
# 20       175068000    EAF      -13.787  250.119            0
# 21       174660000    EAF      -13.787  250.119            0
# 22       231687000   SEIC      318.129  250.119            1
# 23       205819000   BMRN      343.483  250.119            1
# 24       160654000    EOG       80.023  250.119            0
# 25       270717000    CHD      434.782  250.119            1
# 26       246400000    OMC      163.147  250.119            0
# 27        43458000   HUBG       89.700  250.119            0
# 28        65669000   IART      200.623  250.119            0
# 29       194235000     WW      -36.702  254.200            0
# 30        10913000    CRM      545.124  254.200            1
# 31       109243000   POLY      -22.693  254.200            0
# 32      2514600000    MOS      -63.243  254.200            0
# 33        70800000   MLKN       51.279  254.200            0
# 34       112302000   TECH      433.171  254.200            1
# 35        36708000   SCHN      -35.498  254.200            0
# 36        61750000   PSMT      164.871  254.200            0
# 37        22882000   ASYS      -75.529  254.200            0
# 38      1923580000    BEN       -8.871  254.200            0
# 39       114966000    SPH      -33.368  254.200            0
# 40        30791000    TBI       -0.054  254.200            0
# 41        67900000    ABG      660.661  254.200            1
# 42        -4549000   MGTI      -97.468  254.200            0
# 43        13594176   SIGA      -46.460  254.200            0
# 44          416000   AUTO      -41.364  254.200            0
# 45        10747000   PRFT      265.460  254.200            1
# 46        13437000   PDCE      -53.009  254.200            0
# 47       -27100000   RNWK      -85.996  254.200            0
# 48       -39493000   FSLR      -23.754  254.200            0
# 49       -17263000    VHC      -58.929  254.200            0
# 50        -6215000    VHC      -58.929  254.200            0
# 51        73609000   MDRX      -26.776  254.200            0
# 52       162100000     NC      291.540  254.200            1
# 53         1474000   HCCI      111.311  254.200            0
# 54        -6230000   CXDO      130.137  254.200            0
# 55        72372000   MATW       -5.710  254.200            0
# 56        68917000   SANM      160.394  254.200            0
# 57         7449000    SIF      -43.792  254.200            0
# 58        -2409756   KNWN      -95.771  254.200            0
# 59        59220000   BECN      120.901  254.200            0
# 60        12211000   FRPH       70.904  254.200            0
# 61      7074000000    HPQ       63.076  254.200            0
# 62       -24537364   CBAT      -47.143  254.200            0
# 63      -195521000   CIEN      135.744  254.200            0
# 64          242915   MFCO      -19.185  254.200            0
# 65         4653473   RGCO      235.927  254.200            0
# 66       -37693000   IESC     1174.648  254.200            1
# 67          -27256   PGLO      -99.450  254.200            0
# 68        32644000   JOUT      827.580  254.200            1
# 69       -34219000   EMKR       53.697  254.200            0
# 70         1348734   DYSL      -78.542  254.200            0
# 71          -54105   GSTC     -100.000  254.200            0
# 72          358000    JOB      -78.444  254.200            0
# 73         1449000    BDL      146.159  254.200            0
# 74          591000   OPXS      -88.909  254.200            0
# 75        -1109397   GSTX      -98.445  254.200            0
# 76           68857   BUUZ      -99.829  254.200            0
# 77        16229000   PLAB       83.752  254.200            0
# 78        -5025000   STLY      -60.120  254.200            0
# 79         3158981   PBSV      559.082  254.200            1
# 80          -15812   INLX      -98.940  254.200            0
# 81        12291856   GFGY       16.129  254.200            0
# 82       150331000    SNX      435.964  254.200            1
# 83       137953000   LEVI      -10.706  254.200            0
# 84        34100000    DHX      -84.663  254.200            0
# 85       409044000     VG      447.826  254.200            1
# 86       198000000    MAR      257.028  254.200            1
# 87      2839000000    HAL      -45.583  254.200            0
# 88        19000000     MA     1578.084  254.200            1
# 89            1643   MPAD      106.728  254.200            0
# 90        48911000    CCI      357.762  254.200            1
# 91       607000000     CE      250.177  254.200            0
# 92        91808000   AMKR      100.654  254.200            0
# 93     12942000000   INTC      222.657  254.200            0
# 94       153184000    EAF      -19.301  254.200            0
# 95        42247000   FYBR        0.000  254.200            0
# 96       108699000   CTXS      143.887  254.200            0
# 97      8572000000     KO      120.739  254.200            0
# 98       265600000    GPK      372.445  254.200            1
# 99       180675000   ANSS      580.369  254.200            1
# 100        6208791   CEMI       54.573  254.200            0
# 101       20552000   VSEC      148.676  254.200            0
# 102       -6566000   PXLW      -23.243  254.200            0
# 103     -116215000   LXRX      -66.476  254.200            0
# 104       -3854000    BYD      298.712  254.200            1
# 105        2811193    ACU      294.974  254.200            1
# 106      -96853000   GERN      -67.214  254.200            0
# 107      -11588000   TREX     2508.792  254.200            1
# 108       -2710000   PRPH     1344.033  254.200            1
# 109       44198000    HHS      -96.934  254.200            0
# 110        1420000    NLS      864.249  254.200            1
# 111      -14819749   EGLE      -99.961  254.200            0
# 112      -35900000   STRL       32.543  254.200            0
# 113      -10061000   CUTR      172.874  254.200            0
# 114       14318000   BBSI      395.212  254.200            1
# 115       16940194   MODV      773.132  254.200            1
# 116      -32031175   STXS      -85.610  254.200            0
# 117      -23222678   CLSN      -99.423  254.200            0
# 118       14064000   PESI      -31.429  254.200            0
# 119       71378000   EBIX       69.299  254.200            0
# 120         986000   DXYN      -31.635  254.200            0
# 121       -5719903   IMUC        0.000  254.200            0
# 122       -7482636   AMNL      -94.792  254.200            0
# 123         256524   LOAN      579.115  254.200            1
# 124      -13853203   ADYX      -99.860  254.200            0
# 125        7409364   CLTH      -55.556  254.200            0
# 126        -116622   UCIX      -95.875  254.200            0
# 127         -88589   UCIX      -95.875  254.200            0
# 128      -15532000    PAR      907.191  254.200            1
# 129         351848   USIO      816.667  254.200            1
# 130      185251000   URBN        7.387  353.765            0
# 131        -570302   GAXY      -99.907  254.200            0
# 132       26382000   SCVL      451.412  353.765            1
# 133        -475515   NNAX       25.000  254.200            0
# 134       -3723000   CONN      105.579  353.765            0
# 135        -590911   LTUM       -0.769  254.200            0
# 136         853903    HQI      127.216  254.200            0
# 137        -376825   LAKE      129.989  353.765            0
# 138        2090135   BUDZ      -90.833  254.200            0
# 139       -1171921   AGSS      -93.103  254.200            0
# 140        5218000   CAMP       66.511  353.765            0
# 141       -1337472   MICR      -39.273  254.200            0
# 142       11381095   NVEC       88.047  353.765            0
# 143       -4987000   PPIH       23.994  353.765            0
# 144       -2461459   LBSR      -96.491  353.765            0
# 145       29900000    ZWS       84.205  353.765            0
# 146       37212000    PBH      426.215  353.765            1
# 147         746000   SODI      301.733  353.765            0
# 148       -1596208   DBRM      -29.412  353.765            0
# 149        3279000   ESTE      -26.154  353.765            0
# 150       16436900   TESS      -30.840  353.765            0
# 151       38461000    MOD        3.774  353.765            0
# 152       -1429000   RNVA     -100.000  353.765            0
# 153       -8809000   QMCO      -68.386  353.765            0
# 154      -13651066   NXTP      -96.380  353.765            0
# 155        8489000   DAKT      -25.692  353.765            0
# 156      -23040000   CIDM      -91.197  353.765            0
# 157        -503288    UUU      -36.413  353.765            0
# 158        3187771   PFIE       44.986  353.765            0
# 159        8383000    MEI      559.402  353.765            1
# 160     -139216221   FRHC      774.000  353.765            1
# 161      -15058274   ELTP      -66.667  353.765            0
# 162      -20786000   AMWD      361.351  353.765            1
# 163         463116   MICS       92.308  353.765            0
# 164       74174000   TTEC      290.946  254.200            1
# 165     1930200000    MOS       -9.030  353.765            0
# 166       15712410   TENX      -99.817  353.765            0
# 167       41142000    RGP      119.756  353.765            0
# 168         -14763   GBLX      -98.667  353.765            0
# 169        5086000    GPN      499.074  353.765            1
# 170      125174000   OTEX      316.699  353.765            0
# 171     2862000000    STX     1025.385  353.765            1
# 172     3631000000     PG      229.651  353.765            0
# 173        5049000   NAUH      -98.689  353.765            0
# 174      108779000    AIT      254.020  353.765            0
# 175       -1761019   VSYM      -92.000  254.200            0
# 176       -3040000   LTRX      249.362  353.765            0
# 177       79225000   HAIN      134.718  353.765            0
# 178        2198931   TAYD       37.548  353.765            0
# 179      112331000   TECH      691.689  353.765            1
# 180       -3389000   AEHR     3864.407  353.765            1
# 181       74288000   SCSC        0.254  353.765            0
# 182       12917000   AOSL      676.654  353.765            1
# 183         483910   CTIB      -69.510  254.200            0
# 184      -32451000   PSTV      -99.995  254.200            0
# 185         374835   SANW      -37.413  353.765            0
# 186       -4472848   DNAX     -100.000  254.200            0
# 187         511689    EVI     4096.897  353.765            1
# 188      -48514000   MPAA      127.500  353.765            0
# 189        -305309   WESC      -99.800  353.765            0
# 190      -29424000   ATRX      -99.975  254.200            0
# 191       -1768075   SGLY      -52.613  353.765            0
# 192        -485000   SCHN       58.748  353.765            0
# 193       -1416822   SRRE       -7.785  254.200            0
# 194      729700000    IVZ        1.119  254.200            0
# 195        -103468   CUII      650.000  353.765            1
# 196       -6207207   NNVC      -90.667  353.765            0
# 197        -112947   HMLA      -99.700  353.765            0
# 198      180234000   SANM      335.544  353.765            0
# 199     1383800000   SBUX      508.976  353.765            1
# 200      324969000    TDG     1220.113  353.765            1
# 201       75565000   BECN      173.560  353.765            0
# 202        1882000    SPH      -17.749  353.765            0
# 203       12975000   MATW       34.312  353.765            0
# 204        2420000   EACO     1035.135  353.765            1
# 205       -1238054   GRYN      -99.981  353.765            0
# 206          75801   MFCO       11.622  353.765            0
# 207     -144021000   CIEN      521.027  353.765            1

# %%
# save off final dataframe as a CSV
full_df.to_csv('./data/modeling_df')

# %%
final_df = pd.read_csv('./data/modeling_df')

# %%
final_df.drop(columns='Unnamed: 0', axis=1, inplace=True)

# %%
final_df.head()
# Out:
#    year      CIK  AssetsCurrent  LiabilitiesCurrent  \
# 0  2009  1140859     9953753000          9479610000
# 1  2009   829224     2035800000          1581000000
# 2  2009   796343     2473624000           844553000
# 3  2009   875045     2480595000           714942000
# 4  2009   100885     3680000000          2682000000
#
#    NetCashProvidedByUsedInOperatingActivities  \
# 0                                   783763000
# 1                                  1389000000
# 2                                  1117772000
# 3                                  1074898000
# 4                                  3234000000
#
#    NetCashProvidedByUsedInInvestingActivities  \
# 0                               -1.483490e+08
# 1                               -4.211000e+08
# 2                               -1.497096e+09
# 3                               -3.950310e+08
# 4                               -2.175000e+09
#
#    NetCashProvidedByUsedInFinancingActivities  \
# 0                                  -504160000
# 1                                  -642200000
# 2                                   477658000
# 3                                  -724151000
# 4                                  -458000000
#
#    CashAndCashEquivalentsPeriodIncreaseDecrease  OperatingIncomeLoss  \
# 0                                     131254000            883749000
# 1                                     330000000            562000000
# 2                                     113037000            690513000
# 3                                     -44284000           1295427000
# 4                                     601000000           3392000000
#
#    NetIncomeLoss ticker  10yrReturns      SPY  marketBeat?
# 0      503397000    ABC      382.872  230.065            1
# 1      390800000   SBUX     1404.256  230.065            1
# 2      386508000   ADBE      875.543  230.065            1
# 3      970132000   BIIB      528.356  230.065            1
# 4     1898000000    UNP      578.284  230.065            1

# %%
df1 = pd.read_csv('./data/df1')

# %%
df2 = pd.read_csv('./data/df2')

# %%
df3 = pd.read_csv('./data/df3')

# %%
df4 = pd.read_csv('./data/df4')

# %%
df5 = pd.read_csv('./data/df5')

# %%
df6 = pd.read_csv('./data/df6')

# %%
df7 = pd.read_csv('./data/df7')

# %%
df8 = pd.read_csv('./data/df8')

# %%
df9 = pd.read_csv('./data/df9')

# %%
df1['sector'] = df1['ticker'].map(get_sector)
# Out:
# ABC
# SBUX
# ADBE
# BIIB
# UNP

# %%
# append stock sectors into a dictionary if the ticker symbol is not already in the dictionary
for ticker in final_df['ticker']:
    if ticker in sector_dict.keys() or ticker=='PGLO':
        pass
    else:
        sector_dict[ticker] = get_sector(ticker)
# Out:
# JOUT
# EMKR
# DYSL
# GSTC
# JOB
# BDL
# OPXS

# %%
len(sector_dict)
# Out:
# 191

# %%
df1
# Out:
#    Unnamed: 0  year      CIK  AssetsCurrent  LiabilitiesCurrent  \
# 0           0  2009  1140859     9953753000          9479610000
# 1           1  2009   829224     2035800000          1581000000
# 2           2  2009   796343     2473624000           844553000
# 3           3  2009   875045     2480595000           714942000
# 4           4  2009   100885     3680000000          2682000000
#
#    NetCashProvidedByUsedInOperatingActivities  \
# 0                                   783763000
# 1                                  1389000000
# 2                                  1117772000
# 3                                  1074898000
# 4                                  3234000000
#
#    NetCashProvidedByUsedInInvestingActivities  \
# 0                               -1.483490e+08
# 1                               -4.211000e+08
# 2                               -1.497096e+09
# 3                               -3.950310e+08
# 4                               -2.175000e+09
#
#    NetCashProvidedByUsedInFinancingActivities  \
# 0                                  -504160000
# 1                                  -642200000
# 2                                   477658000
# 3                                  -724151000
# 4                                  -458000000
#
#    CashAndCashEquivalentsPeriodIncreaseDecrease  OperatingIncomeLoss  \
# 0                                     131254000            883749000
# 1                                     330000000            562000000
# 2                                     113037000            690513000
# 3                                     -44284000           1295427000
# 4                                     601000000           3392000000
#
#    NetIncomeLoss ticker  10yrReturns      SPY             sector
# 0      503397000    ABC      382.872  230.065         Healthcare
# 1      390800000   SBUX     1404.256  230.065  Consumer Cyclical
# 2      386508000   ADBE      875.543  230.065         Technology
# 3      970132000   BIIB      528.356  230.065         Healthcare
# 4     1898000000    UNP      578.284  230.065        Industrials

# %%
# create a sector column in our final dataframe by mapping the sector dictionary to the ticker column
final_df['sector'] = final_df['ticker'].map(sector_dict)

# %%
final_df.head()
# Out:
#    year      CIK  AssetsCurrent  LiabilitiesCurrent  \
# 0  2009  1140859     9953753000          9479610000
# 1  2009   829224     2035800000          1581000000
# 2  2009   796343     2473624000           844553000
# 3  2009   875045     2480595000           714942000
# 4  2009   100885     3680000000          2682000000
#
#    NetCashProvidedByUsedInOperatingActivities  \
# 0                                   783763000
# 1                                  1389000000
# 2                                  1117772000
# 3                                  1074898000
# 4                                  3234000000
#
#    NetCashProvidedByUsedInInvestingActivities  \
# 0                               -1.483490e+08
# 1                               -4.211000e+08
# 2                               -1.497096e+09
# 3                               -3.950310e+08
# 4                               -2.175000e+09
#
#    NetCashProvidedByUsedInFinancingActivities  \
# 0                                  -504160000
# 1                                  -642200000
# 2                                   477658000
# 3                                  -724151000
# 4                                  -458000000
#
#    CashAndCashEquivalentsPeriodIncreaseDecrease  OperatingIncomeLoss  \
# 0                                     131254000            883749000
# 1                                     330000000            562000000
# 2                                     113037000            690513000
# 3                                     -44284000           1295427000
# 4                                     601000000           3392000000
#
#    NetIncomeLoss ticker  10yrReturns      SPY  marketBeat?             sector
# 0      503397000    ABC      382.872  230.065            1         Healthcare
# 1      390800000   SBUX     1404.256  230.065            1  Consumer Cyclical
# 2      386508000   ADBE      875.543  230.065            1         Technology
# 3      970132000   BIIB      528.356  230.065            1         Healthcare
# 4     1898000000    UNP      578.284  230.065            1        Industrials

# %%
# save our final dataframe to be used in modeling
final_df.to_csv('./data/modeling_df2')
